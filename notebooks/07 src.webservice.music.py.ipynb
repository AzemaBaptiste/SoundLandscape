# %%
import sys
import requests

sys.path.insert(0, "C:/Users/julie/PycharmProjects/SoundLandscape/")

# %% [markdown]
# # Rules

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_params')
res = response.json()

# %% [markdown]
# # Speed enery

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_speed_energy', json={"speed": 60})
response.json()
# Out:
# {'result': 0.10230483759584483, 'success': True}

# %% [markdown]
# # Driver pref

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_driver_preferences', json={"driver": "julien"})
response.json()
# Out:
# {'result': ['latino'], 'success': True}

# %% [markdown]
# # Mood

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_mood', json={"mood": "sad"})
response.json()
# Out:
# {'result': {'target_acousticness': 0.0,
#   'target_danceability': 0.3,
#   'target_energy': 0.3,
#   'target_instrumentalness': 0.0,
#   'target_liveness': 0.0,
#   'target_loudness': 0.0,
#   'target_valence': 0.3},
#  'success': True}

# %% [markdown]
# # Get day_time

# %%
data={"now_time": '2019-03-15T06:03:33+00:00', 'sunrise_time': '2019-03-15T06:03:33+00:00', 'sunset_time': '2019-03-15T17:56:07+00:00'}

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_day_time', json=data)
response.json()
# Out:
# {'result': {'target_acousticness': 0.3,
#   'target_danceability': 0.0,
#   'target_energy': 0.2,
#   'target_instrumentalness': 0.0,
#   'target_liveness': 0.0,
#   'target_loudness': 0.0,
#   'target_valence': 0.2},
#  'success': True}

# %% [markdown]
# # Get reco

# %%
data = {'popularity': 90, 'seed_genres':['r-n-b'], 'country':'FR'}

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_recommendations', json=data)

# %%
response.json()
# Out:
# {'result': {'seeds': [{'afterFilteringSize': 943,
#     'afterRelinkingSize': 926,
#     'href': None,
#     'id': 'r-n-b',
#     'initialPoolSize': 943,
#     'type': 'GENRE'}],
#   'tracks': [{'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aEWnrN8h3MhuFUPRfaVuy'},
#        'href': 'https://api.spotify.com/v1/artists/5aEWnrN8h3MhuFUPRfaVuy',
#        'id': '5aEWnrN8h3MhuFUPRfaVuy',
#        'name': 'Case',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aEWnrN8h3MhuFUPRfaVuy'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3fFb0My3SuhfVMw0rBs5rt'},
#      'href': 'https://api.spotify.com/v1/albums/3fFb0My3SuhfVMw0rBs5rt',
#      'id': '3fFb0My3SuhfVMw0rBs5rt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/a28a824da1f455bb39480a7ba9f1d1cecfd4b177',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/f26e959ebab4ca219d6c32b6c63f23846ba3dbf4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/bc35eed179dd40a82e930acb04e2c3c8d43bd84c',
#        'width': 64}],
#      'name': 'Best Of',
#      'release_date': '2014-05-27',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3fFb0My3SuhfVMw0rBs5rt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aEWnrN8h3MhuFUPRfaVuy'},
#       'href': 'https://api.spotify.com/v1/artists/5aEWnrN8h3MhuFUPRfaVuy',
#       'id': '5aEWnrN8h3MhuFUPRfaVuy',
#       'name': 'Case',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aEWnrN8h3MhuFUPRfaVuy'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3zTOe1BtyTkwNvYZOxXktX'},
#       'href': 'https://api.spotify.com/v1/artists/3zTOe1BtyTkwNvYZOxXktX',
#       'id': '3zTOe1BtyTkwNvYZOxXktX',
#       'name': 'Joe',
#       'type': 'artist',
#       'uri': 'spotify:artist:3zTOe1BtyTkwNvYZOxXktX'}],
#     'disc_number': 1,
#     'duration_ms': 230866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRL19900026'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5UZDh0iz12IiJ8LPClqweA'},
#     'href': 'https://api.spotify.com/v1/tracks/5UZDh0iz12IiJ8LPClqweA',
#     'id': '5UZDh0iz12IiJ8LPClqweA',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1CAw3ethNuSDPf3E7luSFF'},
#      'href': 'https://api.spotify.com/v1/tracks/1CAw3ethNuSDPf3E7luSFF',
#      'id': '1CAw3ethNuSDPf3E7luSFF',
#      'type': 'track',
#      'uri': 'spotify:track:1CAw3ethNuSDPf3E7luSFF'},
#     'name': 'Faded Pictures - From The Rush Hour Soundtrack',
#     'popularity': 50,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5UZDh0iz12IiJ8LPClqweA'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4v6XOdonnfpdTKTRJArG7v'},
#        'href': 'https://api.spotify.com/v1/artists/4v6XOdonnfpdTKTRJArG7v',
#        'id': '4v6XOdonnfpdTKTRJArG7v',
#        'name': 'Tink',
#        'type': 'artist',
#        'uri': 'spotify:artist:4v6XOdonnfpdTKTRJArG7v'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/47KopnVrimQ96IMZqMU6EU'},
#      'href': 'https://api.spotify.com/v1/albums/47KopnVrimQ96IMZqMU6EU',
#      'id': '47KopnVrimQ96IMZqMU6EU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/57ae5ac848570b68bc462560870d79a856a5ba54',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/b202ce9bb81f9bf5238330652e7e44694ced871a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/17ce7dca0ebffc4d196a8045bac831c3d3456c75',
#        'width': 64}],
#      'name': 'Million',
#      'release_date': '2015-05-11',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:47KopnVrimQ96IMZqMU6EU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4v6XOdonnfpdTKTRJArG7v'},
#       'href': 'https://api.spotify.com/v1/artists/4v6XOdonnfpdTKTRJArG7v',
#       'id': '4v6XOdonnfpdTKTRJArG7v',
#       'name': 'Tink',
#       'type': 'artist',
#       'uri': 'spotify:artist:4v6XOdonnfpdTKTRJArG7v'}],
#     'disc_number': 1,
#     'duration_ms': 271493,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM11503944'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Ktsil4bC4hYRWlqMG4qK3'},
#     'href': 'https://api.spotify.com/v1/tracks/1Ktsil4bC4hYRWlqMG4qK3',
#     'id': '1Ktsil4bC4hYRWlqMG4qK3',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Million',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ba2ec6a11f683db86eac8213d22e40109c0d427c?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Ktsil4bC4hYRWlqMG4qK3'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12PSlydMSjEHzSCj9X5qv7'},
#        'href': 'https://api.spotify.com/v1/artists/12PSlydMSjEHzSCj9X5qv7',
#        'id': '12PSlydMSjEHzSCj9X5qv7',
#        'name': 'Baby Bash',
#        'type': 'artist',
#        'uri': 'spotify:artist:12PSlydMSjEHzSCj9X5qv7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/42LlDinsxjsByAqqpZXRp4'},
#      'href': 'https://api.spotify.com/v1/albums/42LlDinsxjsByAqqpZXRp4',
#      'id': '42LlDinsxjsByAqqpZXRp4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e266b420e2ffcaf606de02f9f5e147219cd3d58d',
#        'width': 629},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/852d918fbe696425850b95e28fa33be41f447326',
#        'width': 295},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5e5e7035b90b36bbe765e9d179a077cf4cd66e18',
#        'width': 63}],
#      'name': "Tha Smokin' Nephew",
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:42LlDinsxjsByAqqpZXRp4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12PSlydMSjEHzSCj9X5qv7'},
#       'href': 'https://api.spotify.com/v1/artists/12PSlydMSjEHzSCj9X5qv7',
#       'id': '12PSlydMSjEHzSCj9X5qv7',
#       'name': 'Baby Bash',
#       'type': 'artist',
#       'uri': 'spotify:artist:12PSlydMSjEHzSCj9X5qv7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3sMYEBy0CZFxedcnm9i9hf'},
#       'href': 'https://api.spotify.com/v1/artists/3sMYEBy0CZFxedcnm9i9hf',
#       'id': '3sMYEBy0CZFxedcnm9i9hf',
#       'name': 'Frankie J',
#       'type': 'artist',
#       'uri': 'spotify:artist:3sMYEBy0CZFxedcnm9i9hf'}],
#     'disc_number': 1,
#     'duration_ms': 239026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUR10300765'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Nq5lE0CeOAAAqN4qhkbZU'},
#     'href': 'https://api.spotify.com/v1/tracks/6Nq5lE0CeOAAAqN4qhkbZU',
#     'id': '6Nq5lE0CeOAAAqN4qhkbZU',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Suga Suga',
#     'popularity': 73,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6Nq5lE0CeOAAAqN4qhkbZU'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#        'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#        'id': '31TPClRtHm23RisEBtV3X7',
#        'name': 'Justin Timberlake',
#        'type': 'artist',
#        'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0O82niJ0NpcptYRxogeEZu'},
#      'href': 'https://api.spotify.com/v1/albums/0O82niJ0NpcptYRxogeEZu',
#      'id': '0O82niJ0NpcptYRxogeEZu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/8fcfd07b27039a9a7e4356a028430b1673036849',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/9fbcae99eb8228606f54314d525b188a8702583a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/23800b8bf704ecce107177f7d6e566aa18268a27',
#        'width': 64}],
#      'name': 'The 20/20 Experience (Deluxe Version)',
#      'release_date': '2013-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0O82niJ0NpcptYRxogeEZu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#       'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#       'id': '31TPClRtHm23RisEBtV3X7',
#       'name': 'Justin Timberlake',
#       'type': 'artist',
#       'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'}],
#     'disc_number': 1,
#     'duration_ms': 326280,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC11300004'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6vt0I1cw1YmAIKDJvHVIM5'},
#     'href': 'https://api.spotify.com/v1/tracks/6vt0I1cw1YmAIKDJvHVIM5',
#     'id': '6vt0I1cw1YmAIKDJvHVIM5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Suit & Tie',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2744b13afca5b0b22439b7d49d3505364c5735d1?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6vt0I1cw1YmAIKDJvHVIM5'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KNqYrivNgVCHBssEUSu5B'},
#        'href': 'https://api.spotify.com/v1/artists/5KNqYrivNgVCHBssEUSu5B',
#        'id': '5KNqYrivNgVCHBssEUSu5B',
#        'name': 'Donell Jones',
#        'type': 'artist',
#        'uri': 'spotify:artist:5KNqYrivNgVCHBssEUSu5B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YylipCwfGRhRc4j3vJzwV'},
#      'href': 'https://api.spotify.com/v1/albums/1YylipCwfGRhRc4j3vJzwV',
#      'id': '1YylipCwfGRhRc4j3vJzwV',
#      'images': [{'height': 587,
#        'url': 'https://i.scdn.co/image/1013292fcb3734d23ca5530e43c618aa03a5b9bc',
#        'width': 640},
#       {'height': 275,
#        'url': 'https://i.scdn.co/image/41c5540a714a4930c0f8234fd796574510131d90',
#        'width': 300},
#       {'height': 59,
#        'url': 'https://i.scdn.co/image/be2a8dadf9debb1a5587463b35c246cc72d4ba7c',
#        'width': 64}],
#      'name': 'My Heart',
#      'release_date': '1996-06-04',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:1YylipCwfGRhRc4j3vJzwV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KNqYrivNgVCHBssEUSu5B'},
#       'href': 'https://api.spotify.com/v1/artists/5KNqYrivNgVCHBssEUSu5B',
#       'id': '5KNqYrivNgVCHBssEUSu5B',
#       'name': 'Donell Jones',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KNqYrivNgVCHBssEUSu5B'}],
#     'disc_number': 1,
#     'duration_ms': 222760,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF20000364'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4o1E2c0ye1RlIJJqOM0dqP'},
#     'href': 'https://api.spotify.com/v1/tracks/4o1E2c0ye1RlIJJqOM0dqP',
#     'id': '4o1E2c0ye1RlIJJqOM0dqP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Knocks Me Off My Feet',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f8eb57237da3b68a7573cef3d0d2c3e4db8d206d?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4o1E2c0ye1RlIJJqOM0dqP'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1hfSMy89JzdUmHjxDFXlZ1'},
#      'href': 'https://api.spotify.com/v1/albums/1hfSMy89JzdUmHjxDFXlZ1',
#      'id': '1hfSMy89JzdUmHjxDFXlZ1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/93d72b18aae49bfb590d5ba763cda542b540c735',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/61bccfbbda7e8b0e9abb960ee6f9941833db9845',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/c165b3b34985cafb63908051451cb52b7f511fdb',
#        'width': 64}],
#      'name': 'Insecure: Music from the HBO Original Series, Season 2',
#      'release_date': '2017-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:1hfSMy89JzdUmHjxDFXlZ1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'disc_number': 1,
#     'duration_ms': 242200,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC11702082'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0UQSyryW2vxE88AVFSZs3T'},
#     'href': 'https://api.spotify.com/v1/tracks/0UQSyryW2vxE88AVFSZs3T',
#     'id': '0UQSyryW2vxE88AVFSZs3T',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Quicksand',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab2bca722e0d78b88ad1da912ce283a50284fdf1?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:0UQSyryW2vxE88AVFSZs3T'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27FGXRNruFoOdf1vP8dqcH'},
#        'href': 'https://api.spotify.com/v1/artists/27FGXRNruFoOdf1vP8dqcH',
#        'id': '27FGXRNruFoOdf1vP8dqcH',
#        'name': 'Cassie',
#        'type': 'artist',
#        'uri': 'spotify:artist:27FGXRNruFoOdf1vP8dqcH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0j1qzjaJmsF1FkcICf3hRu'},
#      'href': 'https://api.spotify.com/v1/albums/0j1qzjaJmsF1FkcICf3hRu',
#      'id': '0j1qzjaJmsF1FkcICf3hRu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/931cd05e1b821fadffe5d235110973b0be74cb3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/3d9005f9ad060685be82d9ed3caf84036a9c8b4a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a9e82ed599f7d14847fa0ea70b6a19a5f4546de5',
#        'width': 64}],
#      'name': 'Cassie (U.S. Version)',
#      'release_date': '2006-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0j1qzjaJmsF1FkcICf3hRu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27FGXRNruFoOdf1vP8dqcH'},
#       'href': 'https://api.spotify.com/v1/artists/27FGXRNruFoOdf1vP8dqcH',
#       'id': '27FGXRNruFoOdf1vP8dqcH',
#       'name': 'Cassie',
#       'type': 'artist',
#       'uri': 'spotify:artist:27FGXRNruFoOdf1vP8dqcH'}],
#     'disc_number': 1,
#     'duration_ms': 192213,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBB40610361'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7k6IzwMGpxnRghE7YosnXT'},
#     'href': 'https://api.spotify.com/v1/tracks/7k6IzwMGpxnRghE7YosnXT',
#     'id': '7k6IzwMGpxnRghE7YosnXT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Me & U',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/af06bccc66a9062aa4655fdd22c151c4ae577a54?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7k6IzwMGpxnRghE7YosnXT'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#        'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#        'id': '2wIVse2owClT7go1WT98tk',
#        'name': 'Missy Elliott',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/20t54K6C80QQH7vbcpfJcP'},
#      'href': 'https://api.spotify.com/v1/albums/20t54K6C80QQH7vbcpfJcP',
#      'id': '20t54K6C80QQH7vbcpfJcP',
#      'images': [{'height': 633,
#        'url': 'https://i.scdn.co/image/c94d87f743f11254bdd0ffc5434b59dba851d7d6',
#        'width': 640},
#       {'height': 297,
#        'url': 'https://i.scdn.co/image/0507be05842344647ef44aedd1ccd1f0eaa1e17f',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image/462dd41dd28fd3d7a4e74c24ef542c7e5db2f384',
#        'width': 64}],
#      'name': 'Miss E...So Addictive',
#      'release_date': '2001-05-14',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:20t54K6C80QQH7vbcpfJcP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#       'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#       'id': '2wIVse2owClT7go1WT98tk',
#       'name': 'Missy Elliott',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7r8RF1tN2A4CiGEplkp1oP'},
#       'href': 'https://api.spotify.com/v1/artists/7r8RF1tN2A4CiGEplkp1oP',
#       'id': '7r8RF1tN2A4CiGEplkp1oP',
#       'name': 'Ginuwine',
#       'type': 'artist',
#       'uri': 'spotify:artist:7r8RF1tN2A4CiGEplkp1oP'}],
#     'disc_number': 1,
#     'duration_ms': 299066,
#     'explicit': True,
#     'external_ids': {'isrc': 'USEW20100198'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/53cVCGWe27PNZfb0KNUnjt'},
#     'href': 'https://api.spotify.com/v1/tracks/53cVCGWe27PNZfb0KNUnjt',
#     'id': '53cVCGWe27PNZfb0KNUnjt',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Take Away (feat. Ginuwine)',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a9866490afabba710e5f2cffbe310605b32621ac?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:53cVCGWe27PNZfb0KNUnjt'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Goe2NezNnym45kco2xTk6'},
#        'href': 'https://api.spotify.com/v1/artists/1Goe2NezNnym45kco2xTk6',
#        'id': '1Goe2NezNnym45kco2xTk6',
#        'name': 'Nick Hakim',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Goe2NezNnym45kco2xTk6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6booRahW0CwbWrAkv0cYs9'},
#      'href': 'https://api.spotify.com/v1/albums/6booRahW0CwbWrAkv0cYs9',
#      'id': '6booRahW0CwbWrAkv0cYs9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f176ba036f0fd15657964fd7b715be7cbb66f449',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8e8aa6afbbd4ea4625b05b6617400f1ddee46afd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b9e475efc91aed3f85c41c5e74add16efb64ab3e',
#        'width': 64}],
#      'name': 'Green Twins',
#      'release_date': '2017-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:6booRahW0CwbWrAkv0cYs9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Goe2NezNnym45kco2xTk6'},
#       'href': 'https://api.spotify.com/v1/artists/1Goe2NezNnym45kco2xTk6',
#       'id': '1Goe2NezNnym45kco2xTk6',
#       'name': 'Nick Hakim',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Goe2NezNnym45kco2xTk6'}],
#     'disc_number': 1,
#     'duration_ms': 211826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USATO1600798'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RbKvBeZBMaskx5jRNm43i'},
#     'href': 'https://api.spotify.com/v1/tracks/5RbKvBeZBMaskx5jRNm43i',
#     'id': '5RbKvBeZBMaskx5jRNm43i',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5gN2YGb1DOT5etfqwP66I3'},
#      'href': 'https://api.spotify.com/v1/tracks/5gN2YGb1DOT5etfqwP66I3',
#      'id': '5gN2YGb1DOT5etfqwP66I3',
#      'type': 'track',
#      'uri': 'spotify:track:5gN2YGb1DOT5etfqwP66I3'},
#     'name': 'Needy Bees',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec5a4b108b29b24f669b6ed58bbe206985f3b35e?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5RbKvBeZBMaskx5jRNm43i'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2r09Inibex3C4ZNTUVSG3m'},
#        'href': 'https://api.spotify.com/v1/artists/2r09Inibex3C4ZNTUVSG3m',
#        'id': '2r09Inibex3C4ZNTUVSG3m',
#        'name': 'Keith Sweat',
#        'type': 'artist',
#        'uri': 'spotify:artist:2r09Inibex3C4ZNTUVSG3m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BzXvdpUKDEk612hLc6rZV'},
#      'href': 'https://api.spotify.com/v1/albums/0BzXvdpUKDEk612hLc6rZV',
#      'id': '0BzXvdpUKDEk612hLc6rZV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9032d34a555405e96cf941b46f2f2a4b7aa75a33',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ef1e57c49871f3535a3992c0dfdc3c64a12248be',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/23bec09c57ef0c4e99ac54d377783031c3095d96',
#        'width': 64}],
#      'name': 'Keith Sweat',
#      'release_date': '1996',
#      'release_date_precision': 'year',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0BzXvdpUKDEk612hLc6rZV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2r09Inibex3C4ZNTUVSG3m'},
#       'href': 'https://api.spotify.com/v1/artists/2r09Inibex3C4ZNTUVSG3m',
#       'id': '2r09Inibex3C4ZNTUVSG3m',
#       'name': 'Keith Sweat',
#       'type': 'artist',
#       'uri': 'spotify:artist:2r09Inibex3C4ZNTUVSG3m'}],
#     'disc_number': 1,
#     'duration_ms': 260666,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE19694711'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/69QIVIjPMnI1ABLBqh9P1b'},
#     'href': 'https://api.spotify.com/v1/tracks/69QIVIjPMnI1ABLBqh9P1b',
#     'id': '69QIVIjPMnI1ABLBqh9P1b',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Twisted',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d7373f83c11623d3b2952fe06cd19b6d31534f30?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:69QIVIjPMnI1ABLBqh9P1b'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lHL3ubAMgSasKjNqKb8HF'},
#        'href': 'https://api.spotify.com/v1/artists/6lHL3ubAMgSasKjNqKb8HF',
#        'id': '6lHL3ubAMgSasKjNqKb8HF',
#        'name': 'Mýa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6lHL3ubAMgSasKjNqKb8HF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5SiJ5LeYlLuwCVsWBxKzpA'},
#      'href': 'https://api.spotify.com/v1/albums/5SiJ5LeYlLuwCVsWBxKzpA',
#      'id': '5SiJ5LeYlLuwCVsWBxKzpA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9b86d383211940909de4e9f944e9fa509a105e94',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/84df2f8366fa9b92ac32c5781fea1c41ec21d07a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/dae2b320f9f8ffc4826af5e22f4454101f720b42',
#        'width': 64}],
#      'name': 'Ready for Whatever',
#      'release_date': '2017-09-22',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:5SiJ5LeYlLuwCVsWBxKzpA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lHL3ubAMgSasKjNqKb8HF'},
#       'href': 'https://api.spotify.com/v1/artists/6lHL3ubAMgSasKjNqKb8HF',
#       'id': '6lHL3ubAMgSasKjNqKb8HF',
#       'name': 'Mýa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lHL3ubAMgSasKjNqKb8HF'}],
#     'disc_number': 1,
#     'duration_ms': 202758,
#     'explicit': True,
#     'external_ids': {'isrc': 'USQY51773766'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0VC8OgfuDmdRL3aroED2PX'},
#     'href': 'https://api.spotify.com/v1/tracks/0VC8OgfuDmdRL3aroED2PX',
#     'id': '0VC8OgfuDmdRL3aroED2PX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Ready for Whatever',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/acea70a7337c7ee5703c367f4bfe0d8a9522cd85?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0VC8OgfuDmdRL3aroED2PX'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZS223C6JyBfXasXxrRqOk'},
#        'href': 'https://api.spotify.com/v1/artists/5ZS223C6JyBfXasXxrRqOk',
#        'id': '5ZS223C6JyBfXasXxrRqOk',
#        'name': 'Jhene Aiko',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ZS223C6JyBfXasXxrRqOk'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7CAAClnSiXdMibPT1oyl4k'},
#      'href': 'https://api.spotify.com/v1/albums/7CAAClnSiXdMibPT1oyl4k',
#      'id': '7CAAClnSiXdMibPT1oyl4k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f628893aef29e9ade52780d2bd244f64de2cf1c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/184d644f20169b73880bf72aa83aac6292e97f1d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/39964ae3b395cc99fe0684ba1d585737a0438abe',
#        'width': 64}],
#      'name': 'Trip',
#      'release_date': '2017-09-22',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:7CAAClnSiXdMibPT1oyl4k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZS223C6JyBfXasXxrRqOk'},
#       'href': 'https://api.spotify.com/v1/artists/5ZS223C6JyBfXasXxrRqOk',
#       'id': '5ZS223C6JyBfXasXxrRqOk',
#       'name': 'Jhene Aiko',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZS223C6JyBfXasXxrRqOk'}],
#     'disc_number': 1,
#     'duration_ms': 279453,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71710462'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0PYmO55JPwEWgtyJbkN6mq'},
#     'href': 'https://api.spotify.com/v1/tracks/0PYmO55JPwEWgtyJbkN6mq',
#     'id': '0PYmO55JPwEWgtyJbkN6mq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'New Balance',
#     'popularity': 60,
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0PYmO55JPwEWgtyJbkN6mq'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#        'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#        'id': '5pKCCKE2ajJHZ9KAiaK11H',
#        'name': 'Rihanna',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4UlGauD7ROb3YbVOFMgW5u'},
#      'href': 'https://api.spotify.com/v1/albums/4UlGauD7ROb3YbVOFMgW5u',
#      'id': '4UlGauD7ROb3YbVOFMgW5u',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e1bd4c89d2b558253f41094e65130c9fd2dcbd2c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/545946d7c6090aac56eb3b51d9a95afc1d254a65',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5dd6695ce5463e78f08dd5c640f0b0666d111cb3',
#        'width': 64}],
#      'name': 'ANTI (Deluxe)',
#      'release_date': '2016-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:4UlGauD7ROb3YbVOFMgW5u'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'disc_number': 1,
#     'duration_ms': 219320,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM5FT1600116'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/72TFWvU3wUYdUuxejTTIzt'},
#     'href': 'https://api.spotify.com/v1/tracks/72TFWvU3wUYdUuxejTTIzt',
#     'id': '72TFWvU3wUYdUuxejTTIzt',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/32lmL4vQAAotg6MrJnhlQZ'},
#      'href': 'https://api.spotify.com/v1/tracks/32lmL4vQAAotg6MrJnhlQZ',
#      'id': '32lmL4vQAAotg6MrJnhlQZ',
#      'type': 'track',
#      'uri': 'spotify:track:32lmL4vQAAotg6MrJnhlQZ'},
#     'name': 'Work',
#     'popularity': 77,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:72TFWvU3wUYdUuxejTTIzt'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NIIxcxNHmOoyBx03SfTCD'},
#        'href': 'https://api.spotify.com/v1/artists/0NIIxcxNHmOoyBx03SfTCD',
#        'id': '0NIIxcxNHmOoyBx03SfTCD',
#        'name': 'Tinashe',
#        'type': 'artist',
#        'uri': 'spotify:artist:0NIIxcxNHmOoyBx03SfTCD'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0u3rjsCgagcSxHoRtXMKQo'},
#      'href': 'https://api.spotify.com/v1/albums/0u3rjsCgagcSxHoRtXMKQo',
#      'id': '0u3rjsCgagcSxHoRtXMKQo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3a817d4b1408dd54c40116e9986eb9733805821c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/622e3f50a41241b4ee05c141c8384323c33a3fc1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/9af851428ecaba2d0df3af510970ea3a9789781b',
#        'width': 64}],
#      'name': 'Joyride',
#      'release_date': '2018-04-13',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0u3rjsCgagcSxHoRtXMKQo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NIIxcxNHmOoyBx03SfTCD'},
#       'href': 'https://api.spotify.com/v1/artists/0NIIxcxNHmOoyBx03SfTCD',
#       'id': '0NIIxcxNHmOoyBx03SfTCD',
#       'name': 'Tinashe',
#       'type': 'artist',
#       'uri': 'spotify:artist:0NIIxcxNHmOoyBx03SfTCD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#       'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#       'id': '7c0XG5cIJTrrAgEC3ULPiq',
#       'name': 'Ty Dolla $ign',
#       'type': 'artist',
#       'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vXTefBL93Dj5IqAWq6OTv'},
#       'href': 'https://api.spotify.com/v1/artists/6vXTefBL93Dj5IqAWq6OTv',
#       'id': '6vXTefBL93Dj5IqAWq6OTv',
#       'name': 'French Montana',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vXTefBL93Dj5IqAWq6OTv'}],
#     'disc_number': 1,
#     'duration_ms': 188880,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC11702936'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6XddLa3bdlJJQC6sImufdH'},
#     'href': 'https://api.spotify.com/v1/tracks/6XddLa3bdlJJQC6sImufdH',
#     'id': '6XddLa3bdlJJQC6sImufdH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Me So Bad (feat. Ty Dolla $ign & French Montana)',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7d3935a4bae9cc9cc4f4139b901b2d01ac2ab691?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6XddLa3bdlJJQC6sImufdH'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#        'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#        'id': '7tYKF4w9nC0nq9CsPZTHyP',
#        'name': 'SZA',
#        'type': 'artist',
#        'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/76290XdXVF9rPzGdNRWdCh'},
#      'href': 'https://api.spotify.com/v1/albums/76290XdXVF9rPzGdNRWdCh',
#      'id': '76290XdXVF9rPzGdNRWdCh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/056d5d03db611ad1b9f00b1c3d19b7acf989b62e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/858107cdf591e0257617a751f331f7bc1debcfca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/160e5177a2c4a63d04f94f848fe88f0f3dbe871c',
#        'width': 64}],
#      'name': 'Ctrl',
#      'release_date': '2017-06-09',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:76290XdXVF9rPzGdNRWdCh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6aaMZ3fcfLv4tEbmY7bjRM'},
#       'href': 'https://api.spotify.com/v1/artists/6aaMZ3fcfLv4tEbmY7bjRM',
#       'id': '6aaMZ3fcfLv4tEbmY7bjRM',
#       'name': 'Isaiah Rashad',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aaMZ3fcfLv4tEbmY7bjRM'}],
#     'disc_number': 1,
#     'duration_ms': 245946,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC11701130'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1IgePMOW0qEe1AViWgkal9'},
#     'href': 'https://api.spotify.com/v1/tracks/1IgePMOW0qEe1AViWgkal9',
#     'id': '1IgePMOW0qEe1AViWgkal9',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Pretty Little Birds (feat. Isaiah Rashad)',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dd9fa7abc01464e73afa790b7383db4481c7f6f6?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1IgePMOW0qEe1AViWgkal9'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/756t7CBmWLNYsshVtS6P44'},
#        'href': 'https://api.spotify.com/v1/artists/756t7CBmWLNYsshVtS6P44',
#        'id': '756t7CBmWLNYsshVtS6P44',
#        'name': 'Tone Stith',
#        'type': 'artist',
#        'uri': 'spotify:artist:756t7CBmWLNYsshVtS6P44'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5h0vyhoU8yu6DTBR7BZYpg'},
#      'href': 'https://api.spotify.com/v1/albums/5h0vyhoU8yu6DTBR7BZYpg',
#      'id': '5h0vyhoU8yu6DTBR7BZYpg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/d38a8336392d66865ffb2a4db4a5f1a32aee9f36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/a915d55d890fc1acf3251c0521befde2e45d7954',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/fcc8ae8cd74a6929f0fc31a56cd6d32d872b36db',
#        'width': 64}],
#      'name': 'Can We Talk',
#      'release_date': '2017-10-20',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:5h0vyhoU8yu6DTBR7BZYpg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/756t7CBmWLNYsshVtS6P44'},
#       'href': 'https://api.spotify.com/v1/artists/756t7CBmWLNYsshVtS6P44',
#       'id': '756t7CBmWLNYsshVtS6P44',
#       'name': 'Tone Stith',
#       'type': 'artist',
#       'uri': 'spotify:artist:756t7CBmWLNYsshVtS6P44'}],
#     'disc_number': 1,
#     'duration_ms': 186250,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM24S1702429'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5iaRmiDqUPyuEzi381eOT1'},
#     'href': 'https://api.spotify.com/v1/tracks/5iaRmiDqUPyuEzi381eOT1',
#     'id': '5iaRmiDqUPyuEzi381eOT1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Date',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/72db1d35c97d9bbfd0bc03044f3d4f9904b11654?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5iaRmiDqUPyuEzi381eOT1'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7RZ31TRPVadSFVy1o8os'},
#        'href': 'https://api.spotify.com/v1/artists/3Y7RZ31TRPVadSFVy1o8os',
#        'id': '3Y7RZ31TRPVadSFVy1o8os',
#        'name': 'H.E.R.',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Y7RZ31TRPVadSFVy1o8os'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0pV0Mx07aMApIpF19oSQgY'},
#      'href': 'https://api.spotify.com/v1/albums/0pV0Mx07aMApIpF19oSQgY',
#      'id': '0pV0Mx07aMApIpF19oSQgY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/943d49a6043f3f03d81d632dfa3462bc29586c20',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/4dd269a764e56df17021cdd4874b78b0cedb0079',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0a9b391c8a04099b792e8a7b04e90f8cab1baf4a',
#        'width': 64}],
#      'name': 'H.E.R.',
#      'release_date': '2017-10-20',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0pV0Mx07aMApIpF19oSQgY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7RZ31TRPVadSFVy1o8os'},
#       'href': 'https://api.spotify.com/v1/artists/3Y7RZ31TRPVadSFVy1o8os',
#       'id': '3Y7RZ31TRPVadSFVy1o8os',
#       'name': 'H.E.R.',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y7RZ31TRPVadSFVy1o8os'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#       'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#       'id': '20wkVLutqVOYrc0kxFs7rA',
#       'name': 'Daniel Caesar',
#       'type': 'artist',
#       'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'}],
#     'disc_number': 1,
#     'duration_ms': 209400,
#     'explicit': False,
#     'external_ids': {'isrc': 'CADDS1700022'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4OBZT9EnhYIV17t4pGw7ig'},
#     'href': 'https://api.spotify.com/v1/tracks/4OBZT9EnhYIV17t4pGw7ig',
#     'id': '4OBZT9EnhYIV17t4pGw7ig',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Best Part (feat. Daniel Caesar)',
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/863e2a899be2340af9b7d84432361d8b47433ba8?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4OBZT9EnhYIV17t4pGw7ig'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MT1Wz4G9Z9EVOg4L5zZMS'},
#        'href': 'https://api.spotify.com/v1/artists/1MT1Wz4G9Z9EVOg4L5zZMS',
#        'id': '1MT1Wz4G9Z9EVOg4L5zZMS',
#        'name': 'Tamar Braxton',
#        'type': 'artist',
#        'uri': 'spotify:artist:1MT1Wz4G9Z9EVOg4L5zZMS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1783Mxpt38yxafCtFlgHNF'},
#      'href': 'https://api.spotify.com/v1/albums/1783Mxpt38yxafCtFlgHNF',
#      'id': '1783Mxpt38yxafCtFlgHNF',
#      'images': [{'height': 636,
#        'url': 'https://i.scdn.co/image/3ce5b607f02afed2a1601f70ba8b63f85c6665a0',
#        'width': 640},
#       {'height': 298,
#        'url': 'https://i.scdn.co/image/5f594091f3832442d6e6d980f48ec541ecb9bbfb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/81489c178ace9c11b8c06a973a122c4e17864977',
#        'width': 64}],
#      'name': 'Love and War',
#      'release_date': '2013-09-03',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:1783Mxpt38yxafCtFlgHNF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MT1Wz4G9Z9EVOg4L5zZMS'},
#       'href': 'https://api.spotify.com/v1/artists/1MT1Wz4G9Z9EVOg4L5zZMS',
#       'id': '1MT1Wz4G9Z9EVOg4L5zZMS',
#       'name': 'Tamar Braxton',
#       'type': 'artist',
#       'uri': 'spotify:artist:1MT1Wz4G9Z9EVOg4L5zZMS'}],
#     'disc_number': 1,
#     'duration_ms': 241920,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11301001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3fLBmhcgWkPI47LfVQ8paB'},
#     'href': 'https://api.spotify.com/v1/tracks/3fLBmhcgWkPI47LfVQ8paB',
#     'id': '3fLBmhcgWkPI47LfVQ8paB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Love and War',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/45a996af9e2895131dda2258df657223b6e20a37?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3fLBmhcgWkPI47LfVQ8paB'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5y2Xq6xcjJb2jVM54GHK3t'},
#        'href': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t',
#        'id': '5y2Xq6xcjJb2jVM54GHK3t',
#        'name': 'John Legend',
#        'type': 'artist',
#        'uri': 'spotify:artist:5y2Xq6xcjJb2jVM54GHK3t'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4W6kVnBPgcW8zDYXbRHh2J'},
#      'href': 'https://api.spotify.com/v1/albums/4W6kVnBPgcW8zDYXbRHh2J',
#      'id': '4W6kVnBPgcW8zDYXbRHh2J',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3f891b7b0a3a46beaff1fd66dd31de7b0bd8ae95',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/c0c93155b1def2f5d39fb372d93cbfb1ab78a14a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/e9c0f7c7fb18216d0df78078b3f194a45762ff49',
#        'width': 64}],
#      'name': 'Get Lifted',
#      'release_date': '2005-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:4W6kVnBPgcW8zDYXbRHh2J'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5y2Xq6xcjJb2jVM54GHK3t'},
#       'href': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t',
#       'id': '5y2Xq6xcjJb2jVM54GHK3t',
#       'name': 'John Legend',
#       'type': 'artist',
#       'uri': 'spotify:artist:5y2Xq6xcjJb2jVM54GHK3t'}],
#     'disc_number': 1,
#     'duration_ms': 217466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10413138'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5m4rsr2D2uwMgOgORtpxSA'},
#     'href': 'https://api.spotify.com/v1/tracks/5m4rsr2D2uwMgOgORtpxSA',
#     'id': '5m4rsr2D2uwMgOgORtpxSA',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2S3osqN6ruuoAg1kUvf7u4'},
#      'href': 'https://api.spotify.com/v1/tracks/2S3osqN6ruuoAg1kUvf7u4',
#      'id': '2S3osqN6ruuoAg1kUvf7u4',
#      'type': 'track',
#      'uri': 'spotify:track:2S3osqN6ruuoAg1kUvf7u4'},
#     'name': "Let's Get Lifted",
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1eeb37101b1424a79319e9040f6906a8e5b154bd?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5m4rsr2D2uwMgOgORtpxSA'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#        'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#        'id': '21E3waRsmPlU7jZsS13rcj',
#        'name': 'Ne-Yo',
#        'type': 'artist',
#        'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6gkwOLmk0ALMOjWs5WhAEr'},
#      'href': 'https://api.spotify.com/v1/albums/6gkwOLmk0ALMOjWs5WhAEr',
#      'id': '6gkwOLmk0ALMOjWs5WhAEr',
#      'images': [{'height': 635,
#        'url': 'https://i.scdn.co/image/d1f0addbc529e215cbc95853c5dee3f3345de393',
#        'width': 640},
#       {'height': 298,
#        'url': 'https://i.scdn.co/image/14b3c295dd766668956d6d306f0b5c3a13326d20',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/8c2afbe90e2e8f803143fcd739b4a8e19ac7b2dc',
#        'width': 64}],
#      'name': 'In My Own Words',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:6gkwOLmk0ALMOjWs5WhAEr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#       'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#       'id': '21E3waRsmPlU7jZsS13rcj',
#       'name': 'Ne-Yo',
#       'type': 'artist',
#       'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#     'disc_number': 1,
#     'duration_ms': 220853,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70600316'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/10aWGOqSDBqvNzJ9NeKDbK'},
#     'href': 'https://api.spotify.com/v1/tracks/10aWGOqSDBqvNzJ9NeKDbK',
#     'id': '10aWGOqSDBqvNzJ9NeKDbK',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sexy Love',
#     'popularity': 69,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:10aWGOqSDBqvNzJ9NeKDbK'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xBARhKI09ZTmeePVDWMCf'},
#        'href': 'https://api.spotify.com/v1/artists/1xBARhKI09ZTmeePVDWMCf',
#        'id': '1xBARhKI09ZTmeePVDWMCf',
#        'name': 'Rotimi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1xBARhKI09ZTmeePVDWMCf'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3dpSlV8vyr8wQO7WEzQtra'},
#      'href': 'https://api.spotify.com/v1/albums/3dpSlV8vyr8wQO7WEzQtra',
#      'id': '3dpSlV8vyr8wQO7WEzQtra',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/80908f56ffca5cce8303eb8d3008b33ac99d680f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/94f0a477a854fc270563f0c03835814ea6c0cd2c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/fb9acd8536e2819a9c1241b3fd8cd0d6499714cd',
#        'width': 64}],
#      'name': 'Jeep Music, Vol. 1',
#      'release_date': '2017-08-04',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3dpSlV8vyr8wQO7WEzQtra'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xBARhKI09ZTmeePVDWMCf'},
#       'href': 'https://api.spotify.com/v1/artists/1xBARhKI09ZTmeePVDWMCf',
#       'id': '1xBARhKI09ZTmeePVDWMCf',
#       'name': 'Rotimi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1xBARhKI09ZTmeePVDWMCf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LKo6ZA3RNvKtLa6zDu32S'},
#       'href': 'https://api.spotify.com/v1/artists/1LKo6ZA3RNvKtLa6zDu32S',
#       'id': '1LKo6ZA3RNvKtLa6zDu32S',
#       'name': 'Kranium',
#       'type': 'artist',
# ...
#       'name': 'Jodeci',
#       'type': 'artist',
#       'uri': 'spotify:artist:1eNkUXHPaXyuyC8NAgzykK'}],
#     'disc_number': 1,
#     'duration_ms': 379228,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC10110137'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/43sNw9nvGYGLYnNiwI8oMZ'},
#     'href': 'https://api.spotify.com/v1/tracks/43sNw9nvGYGLYnNiwI8oMZ',
#     'id': '43sNw9nvGYGLYnNiwI8oMZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Freek'n You",
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:43sNw9nvGYGLYnNiwI8oMZ'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1CoZyIx7UvdxT5c8UkMzHd'},
#        'href': 'https://api.spotify.com/v1/artists/1CoZyIx7UvdxT5c8UkMzHd',
#        'id': '1CoZyIx7UvdxT5c8UkMzHd',
#        'name': 'Jorja Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:1CoZyIx7UvdxT5c8UkMzHd'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3y4JiV8jEq11DBjW4vJhwG'},
#      'href': 'https://api.spotify.com/v1/albums/3y4JiV8jEq11DBjW4vJhwG',
#      'id': '3y4JiV8jEq11DBjW4vJhwG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/5bf368bf7d9162213913c7462943cc51cbe76fe6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/dab6b39489b468ba8d550d63c4b58e0875de5182',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/380a0ea64e7820b0be662c3dae60f7acd39acdba',
#        'width': 64}],
#      'name': 'Lost & Found',
#      'release_date': '2018-06-08',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3y4JiV8jEq11DBjW4vJhwG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1CoZyIx7UvdxT5c8UkMzHd'},
#       'href': 'https://api.spotify.com/v1/artists/1CoZyIx7UvdxT5c8UkMzHd',
#       'id': '1CoZyIx7UvdxT5c8UkMzHd',
#       'name': 'Jorja Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:1CoZyIx7UvdxT5c8UkMzHd'}],
#     'disc_number': 1,
#     'duration_ms': 250454,
#     'explicit': False,
#     'external_ids': {'isrc': 'US23A1500072'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Ak3g9JjqjhRb0lE22778S'},
#     'href': 'https://api.spotify.com/v1/tracks/2Ak3g9JjqjhRb0lE22778S',
#     'id': '2Ak3g9JjqjhRb0lE22778S',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5ZFk1GdwbbFwQd40aHyrhO'},
#      'href': 'https://api.spotify.com/v1/tracks/5ZFk1GdwbbFwQd40aHyrhO',
#      'id': '5ZFk1GdwbbFwQd40aHyrhO',
#      'type': 'track',
#      'uri': 'spotify:track:5ZFk1GdwbbFwQd40aHyrhO'},
#     'name': 'Blue Lights',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bd540ae0aa82f96eb60b1f92714d9259a3aa23da?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2Ak3g9JjqjhRb0lE22778S'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2r09Inibex3C4ZNTUVSG3m'},
#        'href': 'https://api.spotify.com/v1/artists/2r09Inibex3C4ZNTUVSG3m',
#        'id': '2r09Inibex3C4ZNTUVSG3m',
#        'name': 'Keith Sweat',
#        'type': 'artist',
#        'uri': 'spotify:artist:2r09Inibex3C4ZNTUVSG3m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BzXvdpUKDEk612hLc6rZV'},
#      'href': 'https://api.spotify.com/v1/albums/0BzXvdpUKDEk612hLc6rZV',
#      'id': '0BzXvdpUKDEk612hLc6rZV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9032d34a555405e96cf941b46f2f2a4b7aa75a33',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ef1e57c49871f3535a3992c0dfdc3c64a12248be',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/23bec09c57ef0c4e99ac54d377783031c3095d96',
#        'width': 64}],
#      'name': 'Keith Sweat',
#      'release_date': '1996',
#      'release_date_precision': 'year',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0BzXvdpUKDEk612hLc6rZV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2r09Inibex3C4ZNTUVSG3m'},
#       'href': 'https://api.spotify.com/v1/artists/2r09Inibex3C4ZNTUVSG3m',
#       'id': '2r09Inibex3C4ZNTUVSG3m',
#       'name': 'Keith Sweat',
#       'type': 'artist',
#       'uri': 'spotify:artist:2r09Inibex3C4ZNTUVSG3m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2kqVmaPdvLEcfaT9oibK27'},
#       'href': 'https://api.spotify.com/v1/artists/2kqVmaPdvLEcfaT9oibK27',
#       'id': '2kqVmaPdvLEcfaT9oibK27',
#       'name': 'Athena Cage',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kqVmaPdvLEcfaT9oibK27'}],
#     'disc_number': 1,
#     'duration_ms': 264773,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE19900159'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4SF1747p541umnykBp352Q'},
#     'href': 'https://api.spotify.com/v1/tracks/4SF1747p541umnykBp352Q',
#     'id': '4SF1747p541umnykBp352Q',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Nobody (feat. Athena Cage)',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d571efb9ae9e8dc367efe40d1de5ef0d79bd0127?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:4SF1747p541umnykBp352Q'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0uNEy4544VZq2KOl7BsLuo'},
#        'href': 'https://api.spotify.com/v1/artists/0uNEy4544VZq2KOl7BsLuo',
#        'id': '0uNEy4544VZq2KOl7BsLuo',
#        'name': 'Lalah Hathaway',
#        'type': 'artist',
#        'uri': 'spotify:artist:0uNEy4544VZq2KOl7BsLuo'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1DtW7edEw935yWRUOCClET'},
#      'href': 'https://api.spotify.com/v1/albums/1DtW7edEw935yWRUOCClET',
#      'id': '1DtW7edEw935yWRUOCClET',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/58c4dc2b2b50506ff0aa6d99825d8852ef1ac254',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/e6fd9ca27140a7c58c389d20f4b6cee58120c386',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/086ea8a71b005f09da40cba2f47717247e288fdb',
#        'width': 64}],
#      'name': 'honestly',
#      'release_date': '2017-10-20',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:1DtW7edEw935yWRUOCClET'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0uNEy4544VZq2KOl7BsLuo'},
#       'href': 'https://api.spotify.com/v1/artists/0uNEy4544VZq2KOl7BsLuo',
#       'id': '0uNEy4544VZq2KOl7BsLuo',
#       'name': 'Lalah Hathaway',
#       'type': 'artist',
#       'uri': 'spotify:artist:0uNEy4544VZq2KOl7BsLuo'}],
#     'disc_number': 1,
#     'duration_ms': 229320,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ96U1700001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/28SQdOU0nZW4UhSJRLefc2'},
#     'href': 'https://api.spotify.com/v1/tracks/28SQdOU0nZW4UhSJRLefc2',
#     'id': '28SQdOU0nZW4UhSJRLefc2',
#     'is_local': False,
#     'is_playable': True,
#     'name': "i can't wait",
#     'popularity': 31,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:28SQdOU0nZW4UhSJRLefc2'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5RTLRtXjbXI2lSXc6jxlAz'},
#        'href': 'https://api.spotify.com/v1/artists/5RTLRtXjbXI2lSXc6jxlAz',
#        'id': '5RTLRtXjbXI2lSXc6jxlAz',
#        'name': 'Ravyn Lenae',
#        'type': 'artist',
#        'uri': 'spotify:artist:5RTLRtXjbXI2lSXc6jxlAz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5NylLkiLTn2sF3U8mZ9bd7'},
#      'href': 'https://api.spotify.com/v1/albums/5NylLkiLTn2sF3U8mZ9bd7',
#      'id': '5NylLkiLTn2sF3U8mZ9bd7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/8d6f7d7556817676869fad936d97f1fa31959e55',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/062e07dbd70859062a00a0c24cb3173a88bb7e84',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/c4717263a0110bc34a54d63fb5bd5293e40f82ce',
#        'width': 64}],
#      'name': 'Midnight Moonlight EP',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:5NylLkiLTn2sF3U8mZ9bd7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5RTLRtXjbXI2lSXc6jxlAz'},
#       'href': 'https://api.spotify.com/v1/artists/5RTLRtXjbXI2lSXc6jxlAz',
#       'id': '5RTLRtXjbXI2lSXc6jxlAz',
#       'name': 'Ravyn Lenae',
#       'type': 'artist',
#       'uri': 'spotify:artist:5RTLRtXjbXI2lSXc6jxlAz'}],
#     'disc_number': 1,
#     'duration_ms': 219648,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21700453'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2QmU4B8fsyWcTQLVDl06Pk'},
#     'href': 'https://api.spotify.com/v1/tracks/2QmU4B8fsyWcTQLVDl06Pk',
#     'id': '2QmU4B8fsyWcTQLVDl06Pk',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Spice',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e840563333c9567cd8a51a7bea76ce61820fca8f?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2QmU4B8fsyWcTQLVDl06Pk'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GN9PivdemQRKjDt4z5Zv8'},
#        'href': 'https://api.spotify.com/v1/artists/7GN9PivdemQRKjDt4z5Zv8',
#        'id': '7GN9PivdemQRKjDt4z5Zv8',
#        'name': 'The Internet',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GN9PivdemQRKjDt4z5Zv8'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/27ThgFMUAx3MXLQ297DzWF'},
#      'href': 'https://api.spotify.com/v1/albums/27ThgFMUAx3MXLQ297DzWF',
#      'id': '27ThgFMUAx3MXLQ297DzWF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b9788aed212f49b286f4e64529b3deae2b3eccb3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/39e48cb091a21a3b8a0b25fb325c16cdfdb6f1d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f0604dbe55024ff13a8f1f8d450b912dbc28df48',
#        'width': 64}],
#      'name': 'Hive Mind',
#      'release_date': '2018-07-20',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:27ThgFMUAx3MXLQ297DzWF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GN9PivdemQRKjDt4z5Zv8'},
#       'href': 'https://api.spotify.com/v1/artists/7GN9PivdemQRKjDt4z5Zv8',
#       'id': '7GN9PivdemQRKjDt4z5Zv8',
#       'name': 'The Internet',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GN9PivdemQRKjDt4z5Zv8'}],
#     'disc_number': 1,
#     'duration_ms': 261640,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11804481'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0JADBJ42q1ab92VOULBh9V'},
#     'href': 'https://api.spotify.com/v1/tracks/0JADBJ42q1ab92VOULBh9V',
#     'id': '0JADBJ42q1ab92VOULBh9V',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Stay the Night',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/732b0f0ff3ef8385cd4f2c3350a3fbc654645305?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0JADBJ42q1ab92VOULBh9V'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KNqYrivNgVCHBssEUSu5B'},
#        'href': 'https://api.spotify.com/v1/artists/5KNqYrivNgVCHBssEUSu5B',
#        'id': '5KNqYrivNgVCHBssEUSu5B',
#        'name': 'Donell Jones',
#        'type': 'artist',
#        'uri': 'spotify:artist:5KNqYrivNgVCHBssEUSu5B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/01riz9JMpPdL99fYhoZaph'},
#      'href': 'https://api.spotify.com/v1/albums/01riz9JMpPdL99fYhoZaph',
#      'id': '01riz9JMpPdL99fYhoZaph',
#      'images': [{'height': 628,
#        'url': 'https://i.scdn.co/image/340df79e365e36749e7b3b468073f54af85befa8',
#        'width': 640},
#       {'height': 294,
#        'url': 'https://i.scdn.co/image/4900c1c75bcb7608af9ee4bab23428b7437a01b2',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image/93d3ed5f62d51f27a511d78aa30e842d43623f70',
#        'width': 64}],
#      'name': 'Where I Wanna Be',
#      'release_date': '1999-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:01riz9JMpPdL99fYhoZaph'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KNqYrivNgVCHBssEUSu5B'},
#       'href': 'https://api.spotify.com/v1/artists/5KNqYrivNgVCHBssEUSu5B',
#       'id': '5KNqYrivNgVCHBssEUSu5B',
#       'name': 'Donell Jones',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KNqYrivNgVCHBssEUSu5B'}],
#     'disc_number': 1,
#     'duration_ms': 192333,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF29900864'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7x5ayrIxbFqXoufyPrAm3M'},
#     'href': 'https://api.spotify.com/v1/tracks/7x5ayrIxbFqXoufyPrAm3M',
#     'id': '7x5ayrIxbFqXoufyPrAm3M',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Shorty (Got Her Eyes on Me)',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ebca593d2e250ae18fe22cc479a8022a8f7a2ed4?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7x5ayrIxbFqXoufyPrAm3M'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2acDkDTWdNFie1HjcFa4Ny'},
#      'href': 'https://api.spotify.com/v1/albums/2acDkDTWdNFie1HjcFa4Ny',
#      'id': '2acDkDTWdNFie1HjcFa4Ny',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/39d4e59532356a393989fcbbe4335f47c6a62ce1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/95453fa449e3edb2005fd3e714e90a2308c8d7f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/bfbedbc19b3d5fd52b079b5b1a78c2e5692692ae',
#        'width': 64}],
#      'name': 'Queen',
#      'release_date': '2018-08-10',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:2acDkDTWdNFie1HjcFa4Ny'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'disc_number': 1,
#     'duration_ms': 279866,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51800139'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Poyf51k7W3NKnsGwAI90B'},
#     'href': 'https://api.spotify.com/v1/tracks/6Poyf51k7W3NKnsGwAI90B',
#     'id': '6Poyf51k7W3NKnsGwAI90B',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Barbie Dreams',
#     'popularity': 73,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6Poyf51k7W3NKnsGwAI90B'}]},
#  'success': True}
