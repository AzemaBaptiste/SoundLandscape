# %%
import sys
import requests

sys.path.insert(0, "C:/Users/julie/PycharmProjects/SoundLandscape/")

# %% [markdown]
# # Rules

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_params')
res = response.json()

# %% [markdown]
# # Speed enery

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_speed_energy', json={"speed": 60})
response.json()
# Out:
# {'result': 0.10230483759584483, 'success': True}

# %% [markdown]
# # Driver pref

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_driver_preferences', json={"driver": "julien"})
response.json()
# Out:
# {'result': ['latino'], 'success': True}

# %% [markdown]
# # Mood

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_mood', json={"mood": "sad"})
response.json()
# Out:
# {'result': {'target_acousticness': 0.0,
#   'target_danceability': 0.3,
#   'target_energy': 0.3,
#   'target_instrumentalness': 0.0,
#   'target_liveness': 0.0,
#   'target_loudness': 0.0,
#   'target_valence': 0.3},
#  'success': True}

# %% [markdown]
# # Get day_time

# %%
data={"now_time": '2019-03-15T06:03:33+00:00', 'sunrise_time': '2019-03-15T06:03:33+00:00', 'sunset_time': '2019-03-15T17:56:07+00:00'}

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_day_time', json=data)
response.json()
# Out:
# {'result': {'target_acousticness': 0.3,
#   'target_danceability': 0.0,
#   'target_energy': 0.2,
#   'target_instrumentalness': 0.0,
#   'target_liveness': 0.0,
#   'target_loudness': 0.0,
#   'target_valence': 0.2},
#  'success': True}

# %% [markdown]
# # Get reco

# %%
data = {'popularity': 90, 'seed_genres':['r-n-b'], 'country':'FR'}

# %%
response = requests.post('http://127.0.0.1:5000/api/music/get_recommendations', json=data)

# %%
response.json()
# Out:
# {'result': {'seeds': [{'afterFilteringSize': 943,
#     'afterRelinkingSize': 926,
#     'href': None,
#     'id': 'r-n-b',
#     'initialPoolSize': 943,
#     'type': 'GENRE'}],
#   'tracks': [{'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CxZzQFUTM6AzgluGwtq5w'},
#        'href': 'https://api.spotify.com/v1/artists/6CxZzQFUTM6AzgluGwtq5w',
#        'id': '6CxZzQFUTM6AzgluGwtq5w',
#        'name': 'Charlie Wilson',
#        'type': 'artist',
#        'uri': 'spotify:artist:6CxZzQFUTM6AzgluGwtq5w'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4vK8vpFwrtYiRpJgQIXDvv'},
#      'href': 'https://api.spotify.com/v1/albums/4vK8vpFwrtYiRpJgQIXDvv',
#      'id': '4vK8vpFwrtYiRpJgQIXDvv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c7cc3190200cace558d7f530e220d8b2e1cff3a0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8048e4dd6b7a2a86eff8361991f1c6edd4f75a52',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/e0e2c15d539b738f6e7324bbee39e19653482057',
#        'width': 64}],
#      'name': 'In It To Win It',
#      'release_date': '2017-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:4vK8vpFwrtYiRpJgQIXDvv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CxZzQFUTM6AzgluGwtq5w'},
#       'href': 'https://api.spotify.com/v1/artists/6CxZzQFUTM6AzgluGwtq5w',
#       'id': '6CxZzQFUTM6AzgluGwtq5w',
#       'name': 'Charlie Wilson',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CxZzQFUTM6AzgluGwtq5w'}],
#     'disc_number': 1,
#     'duration_ms': 225213,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11602786'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/72F3dEUv08TdYCAS4Xs4UA'},
#     'href': 'https://api.spotify.com/v1/tracks/72F3dEUv08TdYCAS4Xs4UA',
#     'id': '72F3dEUv08TdYCAS4Xs4UA',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Chills',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f7b5bd476c9ccaa489a90a419c984e6528e80d54?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:72F3dEUv08TdYCAS4Xs4UA'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#        'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#        'id': '0hCNtLu0JehylgoiP8L4Gh',
#        'name': 'Nicki Minaj',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jem47f4IRH6UaxNAWO6vD'},
#      'href': 'https://api.spotify.com/v1/albums/5jem47f4IRH6UaxNAWO6vD',
#      'id': '5jem47f4IRH6UaxNAWO6vD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/6c169d733a8ce9bd283998b204d4f1903c9054dd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/47428f8177c674290496ce47c6803b88ab6b7e0c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/db60b0661debc7bdcafa28b394be071e60f7fb92',
#        'width': 64}],
#      'name': 'Pink Friday',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:5jem47f4IRH6UaxNAWO6vD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'disc_number': 1,
#     'duration_ms': 279306,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51000722'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4b0JUNVDwcGdStrJD20M1A'},
#     'href': 'https://api.spotify.com/v1/tracks/4b0JUNVDwcGdStrJD20M1A',
#     'id': '4b0JUNVDwcGdStrJD20M1A',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ConttVd0Ebk3dLNquOmh0'},
#      'href': 'https://api.spotify.com/v1/tracks/0ConttVd0Ebk3dLNquOmh0',
#      'id': '0ConttVd0Ebk3dLNquOmh0',
#      'type': 'track',
#      'uri': 'spotify:track:0ConttVd0Ebk3dLNquOmh0'},
#     'name': 'Moment 4 Life',
#     'popularity': 63,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:4b0JUNVDwcGdStrJD20M1A'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4O2YL4ygn6eTBC0w1hyWUM'},
#        'href': 'https://api.spotify.com/v1/artists/4O2YL4ygn6eTBC0w1hyWUM',
#        'id': '4O2YL4ygn6eTBC0w1hyWUM',
#        'name': 'Melanie Fiona',
#        'type': 'artist',
#        'uri': 'spotify:artist:4O2YL4ygn6eTBC0w1hyWUM'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3PWwOV9kUSHZ4EvFFKWLLY'},
#      'href': 'https://api.spotify.com/v1/albums/3PWwOV9kUSHZ4EvFFKWLLY',
#      'id': '3PWwOV9kUSHZ4EvFFKWLLY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/a7a2c60ceabefa5488122268588b8bb151205fa5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/3bed93471b9ff74b85b5ab1387c8566f1d512cbe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f102e07dc8c52bf29c8d8fb38e8ccd459b949330',
#        'width': 64}],
#      'name': 'The MF Life (Deluxe Version)',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3PWwOV9kUSHZ4EvFFKWLLY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4O2YL4ygn6eTBC0w1hyWUM'},
#       'href': 'https://api.spotify.com/v1/artists/4O2YL4ygn6eTBC0w1hyWUM',
#       'id': '4O2YL4ygn6eTBC0w1hyWUM',
#       'name': 'Melanie Fiona',
#       'type': 'artist',
#       'uri': 'spotify:artist:4O2YL4ygn6eTBC0w1hyWUM'}],
#     'disc_number': 1,
#     'duration_ms': 290026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71113587'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3vMIAawCfJdR6A86JGqLc5'},
#     'href': 'https://api.spotify.com/v1/tracks/3vMIAawCfJdR6A86JGqLc5',
#     'id': '3vMIAawCfJdR6A86JGqLc5',
#     'is_local': False,
#     'is_playable': True,
#     'name': '4AM',
#     'popularity': 53,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3vMIAawCfJdR6A86JGqLc5'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KNqYrivNgVCHBssEUSu5B'},
#        'href': 'https://api.spotify.com/v1/artists/5KNqYrivNgVCHBssEUSu5B',
#        'id': '5KNqYrivNgVCHBssEUSu5B',
#        'name': 'Donell Jones',
#        'type': 'artist',
#        'uri': 'spotify:artist:5KNqYrivNgVCHBssEUSu5B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/01riz9JMpPdL99fYhoZaph'},
#      'href': 'https://api.spotify.com/v1/albums/01riz9JMpPdL99fYhoZaph',
#      'id': '01riz9JMpPdL99fYhoZaph',
#      'images': [{'height': 628,
#        'url': 'https://i.scdn.co/image/340df79e365e36749e7b3b468073f54af85befa8',
#        'width': 640},
#       {'height': 294,
#        'url': 'https://i.scdn.co/image/4900c1c75bcb7608af9ee4bab23428b7437a01b2',
#        'width': 300},
#       {'height': 63,
#        'url': 'https://i.scdn.co/image/93d3ed5f62d51f27a511d78aa30e842d43623f70',
#        'width': 64}],
#      'name': 'Where I Wanna Be',
#      'release_date': '1999-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:01riz9JMpPdL99fYhoZaph'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KNqYrivNgVCHBssEUSu5B'},
#       'href': 'https://api.spotify.com/v1/artists/5KNqYrivNgVCHBssEUSu5B',
#       'id': '5KNqYrivNgVCHBssEUSu5B',
#       'name': 'Donell Jones',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KNqYrivNgVCHBssEUSu5B'}],
#     'disc_number': 1,
#     'duration_ms': 192333,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF29900864'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7x5ayrIxbFqXoufyPrAm3M'},
#     'href': 'https://api.spotify.com/v1/tracks/7x5ayrIxbFqXoufyPrAm3M',
#     'id': '7x5ayrIxbFqXoufyPrAm3M',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Shorty (Got Her Eyes on Me)',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ebca593d2e250ae18fe22cc479a8022a8f7a2ed4?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7x5ayrIxbFqXoufyPrAm3M'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27FGXRNruFoOdf1vP8dqcH'},
#        'href': 'https://api.spotify.com/v1/artists/27FGXRNruFoOdf1vP8dqcH',
#        'id': '27FGXRNruFoOdf1vP8dqcH',
#        'name': 'Cassie',
#        'type': 'artist',
#        'uri': 'spotify:artist:27FGXRNruFoOdf1vP8dqcH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0j1qzjaJmsF1FkcICf3hRu'},
#      'href': 'https://api.spotify.com/v1/albums/0j1qzjaJmsF1FkcICf3hRu',
#      'id': '0j1qzjaJmsF1FkcICf3hRu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/931cd05e1b821fadffe5d235110973b0be74cb3e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/3d9005f9ad060685be82d9ed3caf84036a9c8b4a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a9e82ed599f7d14847fa0ea70b6a19a5f4546de5',
#        'width': 64}],
#      'name': 'Cassie (U.S. Version)',
#      'release_date': '2006-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0j1qzjaJmsF1FkcICf3hRu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27FGXRNruFoOdf1vP8dqcH'},
#       'href': 'https://api.spotify.com/v1/artists/27FGXRNruFoOdf1vP8dqcH',
#       'id': '27FGXRNruFoOdf1vP8dqcH',
#       'name': 'Cassie',
#       'type': 'artist',
#       'uri': 'spotify:artist:27FGXRNruFoOdf1vP8dqcH'}],
#     'disc_number': 1,
#     'duration_ms': 192213,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBB40610361'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7k6IzwMGpxnRghE7YosnXT'},
#     'href': 'https://api.spotify.com/v1/tracks/7k6IzwMGpxnRghE7YosnXT',
#     'id': '7k6IzwMGpxnRghE7YosnXT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Me & U',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/af06bccc66a9062aa4655fdd22c151c4ae577a54?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7k6IzwMGpxnRghE7YosnXT'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rkVyNGXEgeUqKkB5ccK83'},
#        'href': 'https://api.spotify.com/v1/artists/5rkVyNGXEgeUqKkB5ccK83',
#        'id': '5rkVyNGXEgeUqKkB5ccK83',
#        'name': 'Ashanti',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rkVyNGXEgeUqKkB5ccK83'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63VSULTUoOtDE9E8qKj5GY'},
#      'href': 'https://api.spotify.com/v1/albums/63VSULTUoOtDE9E8qKj5GY',
#      'id': '63VSULTUoOtDE9E8qKj5GY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/32a472f85ea1f9d5415b54ae3796e5b9a4be23a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/c4b902570978a252ce28a5b11e476dff6f1a0944',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/619cdae7ec2eead35306b3c16e600b828a1ef8eb',
#        'width': 64}],
#      'name': 'Say Less (feat. Ty Dolla $ign)',
#      'release_date': '2018-03-23',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:63VSULTUoOtDE9E8qKj5GY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rkVyNGXEgeUqKkB5ccK83'},
#       'href': 'https://api.spotify.com/v1/artists/5rkVyNGXEgeUqKkB5ccK83',
#       'id': '5rkVyNGXEgeUqKkB5ccK83',
#       'name': 'Ashanti',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rkVyNGXEgeUqKkB5ccK83'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#       'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#       'id': '7c0XG5cIJTrrAgEC3ULPiq',
#       'name': 'Ty Dolla $ign',
#       'type': 'artist',
#       'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'}],
#     'disc_number': 1,
#     'duration_ms': 196571,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1189689'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ygfSHAl7aW40FHDQjSsD8'},
#     'href': 'https://api.spotify.com/v1/tracks/0ygfSHAl7aW40FHDQjSsD8',
#     'id': '0ygfSHAl7aW40FHDQjSsD8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Say Less (feat. Ty Dolla $ign)',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ffcc713503dfccc7688029f23c6d2541915639ed?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ygfSHAl7aW40FHDQjSsD8'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2r09Inibex3C4ZNTUVSG3m'},
#        'href': 'https://api.spotify.com/v1/artists/2r09Inibex3C4ZNTUVSG3m',
#        'id': '2r09Inibex3C4ZNTUVSG3m',
#        'name': 'Keith Sweat',
#        'type': 'artist',
#        'uri': 'spotify:artist:2r09Inibex3C4ZNTUVSG3m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BzXvdpUKDEk612hLc6rZV'},
#      'href': 'https://api.spotify.com/v1/albums/0BzXvdpUKDEk612hLc6rZV',
#      'id': '0BzXvdpUKDEk612hLc6rZV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9032d34a555405e96cf941b46f2f2a4b7aa75a33',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ef1e57c49871f3535a3992c0dfdc3c64a12248be',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/23bec09c57ef0c4e99ac54d377783031c3095d96',
#        'width': 64}],
#      'name': 'Keith Sweat',
#      'release_date': '1996',
#      'release_date_precision': 'year',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:0BzXvdpUKDEk612hLc6rZV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2r09Inibex3C4ZNTUVSG3m'},
#       'href': 'https://api.spotify.com/v1/artists/2r09Inibex3C4ZNTUVSG3m',
#       'id': '2r09Inibex3C4ZNTUVSG3m',
#       'name': 'Keith Sweat',
#       'type': 'artist',
#       'uri': 'spotify:artist:2r09Inibex3C4ZNTUVSG3m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2kqVmaPdvLEcfaT9oibK27'},
#       'href': 'https://api.spotify.com/v1/artists/2kqVmaPdvLEcfaT9oibK27',
#       'id': '2kqVmaPdvLEcfaT9oibK27',
#       'name': 'Athena Cage',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kqVmaPdvLEcfaT9oibK27'}],
#     'disc_number': 1,
#     'duration_ms': 264773,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE19900159'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4SF1747p541umnykBp352Q'},
#     'href': 'https://api.spotify.com/v1/tracks/4SF1747p541umnykBp352Q',
#     'id': '4SF1747p541umnykBp352Q',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Nobody (feat. Athena Cage)',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d571efb9ae9e8dc367efe40d1de5ef0d79bd0127?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:4SF1747p541umnykBp352Q'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fikk4h5qbEebqK2Fc6e48'},
#        'href': 'https://api.spotify.com/v1/artists/5fikk4h5qbEebqK2Fc6e48',
#        'id': '5fikk4h5qbEebqK2Fc6e48',
#        'name': 'En Vogue',
#        'type': 'artist',
#        'uri': 'spotify:artist:5fikk4h5qbEebqK2Fc6e48'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7d2qNq4zap02SoWdvr0caA'},
#      'href': 'https://api.spotify.com/v1/albums/7d2qNq4zap02SoWdvr0caA',
#      'id': '7d2qNq4zap02SoWdvr0caA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3856ebadd8a1544d60a108b79a40b2752fecb2f6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/769338f8c5a898943471b36ff0817b297034114f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b4aea611932feacc9d98bf8af38253557d1a9346',
#        'width': 64}],
#      'name': 'Funky Divas',
#      'release_date': '1992-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:7d2qNq4zap02SoWdvr0caA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fikk4h5qbEebqK2Fc6e48'},
#       'href': 'https://api.spotify.com/v1/artists/5fikk4h5qbEebqK2Fc6e48',
#       'id': '5fikk4h5qbEebqK2Fc6e48',
#       'name': 'En Vogue',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fikk4h5qbEebqK2Fc6e48'}],
#     'disc_number': 1,
#     'duration_ms': 281613,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEW19200001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3R97rNX7JnmshCWBwOSFet'},
#     'href': 'https://api.spotify.com/v1/tracks/3R97rNX7JnmshCWBwOSFet',
#     'id': '3R97rNX7JnmshCWBwOSFet',
#     'is_local': False,
#     'is_playable': True,
#     'name': "My Lovin' (You're Never Gonna Get It)",
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5d8d1f7fe6368ceedc942ec7787cfc157a772a11?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3R97rNX7JnmshCWBwOSFet'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2retT7MFwHDVTeGKDdybEx'},
#        'href': 'https://api.spotify.com/v1/artists/2retT7MFwHDVTeGKDdybEx',
#        'id': '2retT7MFwHDVTeGKDdybEx',
#        'name': 'K. Michelle',
#        'type': 'artist',
#        'uri': 'spotify:artist:2retT7MFwHDVTeGKDdybEx'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3GmtcEBnUUnOnS53jTMYl6'},
#      'href': 'https://api.spotify.com/v1/albums/3GmtcEBnUUnOnS53jTMYl6',
#      'id': '3GmtcEBnUUnOnS53jTMYl6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/a3e2e1aa4fbe8b34fbb334768b37713c5bec7577',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/88ceacadda2b6fae517508b2ada9167ff46094d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/6c68ff145eb70c8ee1d6015e7fd9ced1a620b5dc',
#        'width': 64}],
#      'name': 'Either Way (feat. Chris Brown)',
#      'release_date': '2017-09-15',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3GmtcEBnUUnOnS53jTMYl6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2retT7MFwHDVTeGKDdybEx'},
#       'href': 'https://api.spotify.com/v1/artists/2retT7MFwHDVTeGKDdybEx',
#       'id': '2retT7MFwHDVTeGKDdybEx',
#       'name': 'K. Michelle',
#       'type': 'artist',
#       'uri': 'spotify:artist:2retT7MFwHDVTeGKDdybEx'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#       'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#       'id': '7bXgB6jMjp9ATFy66eO08Z',
#       'name': 'Chris Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#     'disc_number': 1,
#     'duration_ms': 254095,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21703653'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4UeLehlKZDo61XZrOhr5jr'},
#     'href': 'https://api.spotify.com/v1/tracks/4UeLehlKZDo61XZrOhr5jr',
#     'id': '4UeLehlKZDo61XZrOhr5jr',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Either Way (feat. Chris Brown)',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b390c18b9c493342483a91cf0a1e632ae2be0535?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4UeLehlKZDo61XZrOhr5jr'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y8cdNmUJH7yBTd9yOvr5i'},
#        'href': 'https://api.spotify.com/v1/artists/1Y8cdNmUJH7yBTd9yOvr5i',
#        'id': '1Y8cdNmUJH7yBTd9yOvr5i',
#        'name': "Destiny's Child",
#        'type': 'artist',
#        'uri': 'spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3xjdyJjSMNsSRkj3GTmBLi'},
#      'href': 'https://api.spotify.com/v1/albums/3xjdyJjSMNsSRkj3GTmBLi',
#      'id': '3xjdyJjSMNsSRkj3GTmBLi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/2e7c50a42a1904154866551d63205bc50a02d02f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/87f1fc8c31650b0723bcfb9b57e41e7e6ce4fe7e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0b265a96a4b34eeae6368bdb78912bfe4c90746e',
#        'width': 64}],
#      'name': 'Destiny Fulfilled',
#      'release_date': '2004',
#      'release_date_precision': 'year',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3xjdyJjSMNsSRkj3GTmBLi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y8cdNmUJH7yBTd9yOvr5i'},
#       'href': 'https://api.spotify.com/v1/artists/1Y8cdNmUJH7yBTd9yOvr5i',
#       'id': '1Y8cdNmUJH7yBTd9yOvr5i',
#       'name': "Destiny's Child",
#       'type': 'artist',
#       'uri': 'spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i'}],
#     'disc_number': 1,
#     'duration_ms': 245400,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10413905'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0FZvjrHpAmLKj574M4VwrF'},
#     'href': 'https://api.spotify.com/v1/tracks/0FZvjrHpAmLKj574M4VwrF',
#     'id': '0FZvjrHpAmLKj574M4VwrF',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Cater 2 U',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7083ad060283d2db0ea455b96a2041239a900615?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0FZvjrHpAmLKj574M4VwrF'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3UjPnt2nRmw10N58bBeNOg'},
#        'href': 'https://api.spotify.com/v1/artists/3UjPnt2nRmw10N58bBeNOg',
#        'id': '3UjPnt2nRmw10N58bBeNOg',
#        'name': 'Xavier Omär',
#        'type': 'artist',
#        'uri': 'spotify:artist:3UjPnt2nRmw10N58bBeNOg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/66qApGd5cFvpgW9dw9agO1'},
#      'href': 'https://api.spotify.com/v1/albums/66qApGd5cFvpgW9dw9agO1',
#      'id': '66qApGd5cFvpgW9dw9agO1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/bc9fd84926a0e67b415bd6562b040c002b777562',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/13da4b8b3ca687406ff797f586ac751567d49257',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/9f8139193aef924164721811e2c32de4b9dd9b51',
#        'width': 64}],
#      'name': 'Afraid',
#      'release_date': '2017-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:66qApGd5cFvpgW9dw9agO1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3UjPnt2nRmw10N58bBeNOg'},
#       'href': 'https://api.spotify.com/v1/artists/3UjPnt2nRmw10N58bBeNOg',
#       'id': '3UjPnt2nRmw10N58bBeNOg',
#       'name': 'Xavier Omär',
#       'type': 'artist',
#       'uri': 'spotify:artist:3UjPnt2nRmw10N58bBeNOg'}],
#     'disc_number': 1,
#     'duration_ms': 220043,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM24S1700711'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2zIkPM6r0yEjWt18qG3jP3'},
#     'href': 'https://api.spotify.com/v1/tracks/2zIkPM6r0yEjWt18qG3jP3',
#     'id': '2zIkPM6r0yEjWt18qG3jP3',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Afraid',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/691ca80be0baf35920df62d7b846c929c7b14d20?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2zIkPM6r0yEjWt18qG3jP3'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4mwXUEKaW4ftbncf9Hi58l'},
#        'href': 'https://api.spotify.com/v1/artists/4mwXUEKaW4ftbncf9Hi58l',
#        'id': '4mwXUEKaW4ftbncf9Hi58l',
#        'name': 'Tank',
#        'type': 'artist',
#        'uri': 'spotify:artist:4mwXUEKaW4ftbncf9Hi58l'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2P723Vzun1R14cqiwfX7Fa'},
#      'href': 'https://api.spotify.com/v1/albums/2P723Vzun1R14cqiwfX7Fa',
#      'id': '2P723Vzun1R14cqiwfX7Fa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/bfae78b82c6d498aae43386b0704ced30d674039',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/a73ab73fea19f1b1ca61d82729638b92de39f62b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/c5cd5a0854b7c094bc7d062d62f5a6abd73f88b8',
#        'width': 64}],
#      'name': 'SAVAGE',
#      'release_date': '2017-09-29',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:2P723Vzun1R14cqiwfX7Fa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4mwXUEKaW4ftbncf9Hi58l'},
#       'href': 'https://api.spotify.com/v1/artists/4mwXUEKaW4ftbncf9Hi58l',
#       'id': '4mwXUEKaW4ftbncf9Hi58l',
#       'name': 'Tank',
#       'type': 'artist',
#       'uri': 'spotify:artist:4mwXUEKaW4ftbncf9Hi58l'}],
#     'disc_number': 1,
#     'duration_ms': 270823,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21703289'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WkUwJLIGSD9Azkekq2NJW'},
#     'href': 'https://api.spotify.com/v1/tracks/3WkUwJLIGSD9Azkekq2NJW',
#     'id': '3WkUwJLIGSD9Azkekq2NJW',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sexy',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5505963854145deb05f1873d743e8343b4a799a?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3WkUwJLIGSD9Azkekq2NJW'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6gbGGM0E8Q1hE511psqxL0'},
#        'href': 'https://api.spotify.com/v1/artists/6gbGGM0E8Q1hE511psqxL0',
#        'id': '6gbGGM0E8Q1hE511psqxL0',
#        'name': 'Ray J',
#        'type': 'artist',
#        'uri': 'spotify:artist:6gbGGM0E8Q1hE511psqxL0'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6976UxfTkqcI4CjrY9z4KW'},
#      'href': 'https://api.spotify.com/v1/albums/6976UxfTkqcI4CjrY9z4KW',
#      'id': '6976UxfTkqcI4CjrY9z4KW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/213938489e21dc3e1bd1aca3a890b38542926bdd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7250dd8904a09b4a684ec9d0ddb35a0329a7d875',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/bb702de357151ad3c4d64a079f0ece272ee7fc0d',
#        'width': 64}],
#      'name': 'All I Feel',
#      'release_date': '2008-04-08',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:6976UxfTkqcI4CjrY9z4KW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6gbGGM0E8Q1hE511psqxL0'},
#       'href': 'https://api.spotify.com/v1/artists/6gbGGM0E8Q1hE511psqxL0',
#       'id': '6gbGGM0E8Q1hE511psqxL0',
#       'name': 'Ray J',
#       'type': 'artist',
#       'uri': 'spotify:artist:6gbGGM0E8Q1hE511psqxL0'}],
#     'disc_number': 1,
#     'duration_ms': 204040,
#     'explicit': True,
#     'external_ids': {'isrc': 'USKO10702948'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0DdpxWfVvUGgkJv5536tiF'},
#     'href': 'https://api.spotify.com/v1/tracks/0DdpxWfVvUGgkJv5536tiF',
#     'id': '0DdpxWfVvUGgkJv5536tiF',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sexy Can I feat. Yung Berg',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c57b030f4c0a378d9127ee17584e710b068b0946?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0DdpxWfVvUGgkJv5536tiF'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PgleR09JVnm3zY1fW3XBA'},
#      'href': 'https://api.spotify.com/v1/albums/4PgleR09JVnm3zY1fW3XBA',
#      'id': '4PgleR09JVnm3zY1fW3XBA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/bf41f93f8c895eff007b88bd2e23e12dfe078792',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/63ddbd647a5a4e672da6b6eb29cfc38c985bffca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f77f484d87a4b84e611af30011c381f9ccef0d0b',
#        'width': 64}],
#      'name': '24K Magic',
#      'release_date': '2016-11-17',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:4PgleR09JVnm3zY1fW3XBA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'disc_number': 1,
#     'duration_ms': 206693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21602948'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0KKkJNfGyhkQ5aFogxQAPU'},
#     'href': 'https://api.spotify.com/v1/tracks/0KKkJNfGyhkQ5aFogxQAPU',
#     'id': '0KKkJNfGyhkQ5aFogxQAPU',
#     'is_local': False,
#     'is_playable': True,
#     'name': "That's What I Like",
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f09116ce18bd77f543e68a925e5a96509e79ac6a?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0KKkJNfGyhkQ5aFogxQAPU'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2MGT7CYlixSPxAnnkhLpaA'},
#        'href': 'https://api.spotify.com/v1/artists/2MGT7CYlixSPxAnnkhLpaA',
#        'id': '2MGT7CYlixSPxAnnkhLpaA',
#        'name': 'Next',
#        'type': 'artist',
#        'uri': 'spotify:artist:2MGT7CYlixSPxAnnkhLpaA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7hZCQWhRcrmJMgCOdHfVm5'},
#      'href': 'https://api.spotify.com/v1/albums/7hZCQWhRcrmJMgCOdHfVm5',
#      'id': '7hZCQWhRcrmJMgCOdHfVm5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/2f9b1343c715ac6c1c38f55dd1450f401de06e58',
#        'width': 637},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/b58b339d104a20567b30eab96f9261b30943b62a',
#        'width': 299},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/dd8eb6704466302888e6ca176d9d7b8ae0b76fbe',
#        'width': 64}],
#      'name': 'Welcome II Nextasy',
#      'release_date': '2000-06-20',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:7hZCQWhRcrmJMgCOdHfVm5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2MGT7CYlixSPxAnnkhLpaA'},
#       'href': 'https://api.spotify.com/v1/artists/2MGT7CYlixSPxAnnkhLpaA',
#       'id': '2MGT7CYlixSPxAnnkhLpaA',
#       'name': 'Next',
#       'type': 'artist',
#       'uri': 'spotify:artist:2MGT7CYlixSPxAnnkhLpaA'}],
#     'disc_number': 1,
#     'duration_ms': 243466,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAR10000320'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1NNDZc9BHaWe9JqIsPRlNV'},
#     'href': 'https://api.spotify.com/v1/tracks/1NNDZc9BHaWe9JqIsPRlNV',
#     'id': '1NNDZc9BHaWe9JqIsPRlNV',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Wifey - Club Mix/Dirty Version',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/39c455043cbd24e259947e9efe7cb5a5e2ea73c6?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1NNDZc9BHaWe9JqIsPRlNV'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HzKw8XcD0piJmDrrPRCYk'},
#        'href': 'https://api.spotify.com/v1/artists/4HzKw8XcD0piJmDrrPRCYk',
#        'id': '4HzKw8XcD0piJmDrrPRCYk',
#        'name': 'Majid Jordan',
#        'type': 'artist',
#        'uri': 'spotify:artist:4HzKw8XcD0piJmDrrPRCYk'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7awpB1UEVeDF6h8mGMssTI'},
#      'href': 'https://api.spotify.com/v1/albums/7awpB1UEVeDF6h8mGMssTI',
#      'id': '7awpB1UEVeDF6h8mGMssTI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/8ce9cc5d6312a2062bde09500dc8357d60ac5680',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/bb55f672619aba6af566a30fce04fa3b7d17774e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/06430a025a2aad491b8e4f23862b94b0f2e98878',
#        'width': 64}],
#      'name': 'Majid Jordan',
#      'release_date': '2016-02-05',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:7awpB1UEVeDF6h8mGMssTI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HzKw8XcD0piJmDrrPRCYk'},
#       'href': 'https://api.spotify.com/v1/artists/4HzKw8XcD0piJmDrrPRCYk',
#       'id': '4HzKw8XcD0piJmDrrPRCYk',
#       'name': 'Majid Jordan',
#       'type': 'artist',
#       'uri': 'spotify:artist:4HzKw8XcD0piJmDrrPRCYk'}],
#     'disc_number': 1,
#     'duration_ms': 201466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11515053'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1X1y6CQmAejhN8oeFtouje'},
#     'href': 'https://api.spotify.com/v1/tracks/1X1y6CQmAejhN8oeFtouje',
#     'id': '1X1y6CQmAejhN8oeFtouje',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'King City',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/69b3244163095eeb85c547db6907a48df050ff94?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:1X1y6CQmAejhN8oeFtouje'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tMm1dU6Gn04VAZ9ClHcIZ'},
#        'href': 'https://api.spotify.com/v1/artists/4tMm1dU6Gn04VAZ9ClHcIZ',
#        'id': '4tMm1dU6Gn04VAZ9ClHcIZ',
#        'name': 'Jacquees',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tMm1dU6Gn04VAZ9ClHcIZ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/03AdJ15pTDdmxry6qkKwlO'},
#      'href': 'https://api.spotify.com/v1/albums/03AdJ15pTDdmxry6qkKwlO',
#      'id': '03AdJ15pTDdmxry6qkKwlO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/650fef74c58786abe83dd09b4f622e348faa3436',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7fd9a26704040488d3df159ab7d8767b5f706aee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/91b764855ba82de3ddd040a3cb2c7f646deeaffa',
#        'width': 64}],
#      'name': '4275 (Bonus Version)',
#      'release_date': '2018-09-07',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:03AdJ15pTDdmxry6qkKwlO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tMm1dU6Gn04VAZ9ClHcIZ'},
#       'href': 'https://api.spotify.com/v1/artists/4tMm1dU6Gn04VAZ9ClHcIZ',
#       'id': '4tMm1dU6Gn04VAZ9ClHcIZ',
#       'name': 'Jacquees',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tMm1dU6Gn04VAZ9ClHcIZ'}],
#     'disc_number': 1,
#     'duration_ms': 217386,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCM51800045'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/01jIO8SJFnpSiNLH1JaBZ5'},
#     'href': 'https://api.spotify.com/v1/tracks/01jIO8SJFnpSiNLH1JaBZ5',
#     'id': '01jIO8SJFnpSiNLH1JaBZ5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'You',
#     'popularity': 77,
#     'preview_url': None,
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:01jIO8SJFnpSiNLH1JaBZ5'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rHl3rSgCnHhOlVB87ZxyF'},
#        'href': 'https://api.spotify.com/v1/artists/3rHl3rSgCnHhOlVB87ZxyF',
#        'id': '3rHl3rSgCnHhOlVB87ZxyF',
#        'name': 'Kevin Hart',
#        'type': 'artist',
#        'uri': 'spotify:artist:3rHl3rSgCnHhOlVB87ZxyF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3AFjaBvKk8vtVkaTtXA4QY'},
#      'href': 'https://api.spotify.com/v1/albums/3AFjaBvKk8vtVkaTtXA4QY',
#      'id': '3AFjaBvKk8vtVkaTtXA4QY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/df80f896b2c5001ee2415d7cf1a39fe72095596e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/35b33db258424b923bde7b6b4afb84c4417e6755',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/706f42aa19d9f3cfbb52767b702b8f8e17c9bf22',
#        'width': 64}],
#      'name': 'Kevin Hart: What Now? (The Mixtape Presents Chocolate Droppa) [Original Motion Picture Soundtrack]',
#      'release_date': '2016-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3AFjaBvKk8vtVkaTtXA4QY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rHl3rSgCnHhOlVB87ZxyF'},
#       'href': 'https://api.spotify.com/v1/artists/3rHl3rSgCnHhOlVB87ZxyF',
#       'id': '3rHl3rSgCnHhOlVB87ZxyF',
#       'name': 'Kevin Hart',
#       'type': 'artist',
#       'uri': 'spotify:artist:3rHl3rSgCnHhOlVB87ZxyF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2iojnBLj0qIMiKPvVhLnsH'},
#       'href': 'https://api.spotify.com/v1/artists/2iojnBLj0qIMiKPvVhLnsH',
#       'id': '2iojnBLj0qIMiKPvVhLnsH',
#       'name': 'Trey Songz',
#       'type': 'artist',
#       'uri': 'spotify:artist:2iojnBLj0qIMiKPvVhLnsH'}],
#     'disc_number': 1,
#     'duration_ms': 232806,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71609720'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wasgXy8PI6t4EfA49YnXE'},
#     'href': 'https://api.spotify.com/v1/tracks/0wasgXy8PI6t4EfA49YnXE',
#     'id': '0wasgXy8PI6t4EfA49YnXE',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Push It On Me - From “What Now?”',
#     'popularity': 52,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0wasgXy8PI6t4EfA49YnXE'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2iojnBLj0qIMiKPvVhLnsH'},
#        'href': 'https://api.spotify.com/v1/artists/2iojnBLj0qIMiKPvVhLnsH',
#        'id': '2iojnBLj0qIMiKPvVhLnsH',
#        'name': 'Trey Songz',
#        'type': 'artist',
#        'uri': 'spotify:artist:2iojnBLj0qIMiKPvVhLnsH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5gQtvMHA7yqdzKXrHpe63C'},
#      'href': 'https://api.spotify.com/v1/albums/5gQtvMHA7yqdzKXrHpe63C',
#      'id': '5gQtvMHA7yqdzKXrHpe63C',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/bfe189c3573661abaf7843d24a61dca139ff69f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/0a8a895c35b24e1f3bf09fc47803e5334a81225d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/403b777aa4aed9056767e01f1ccdb90d943785da',
#        'width': 64}],
#      'name': 'Tremaine The Album',
#      'release_date': '2017-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:5gQtvMHA7yqdzKXrHpe63C'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2iojnBLj0qIMiKPvVhLnsH'},
#       'href': 'https://api.spotify.com/v1/artists/2iojnBLj0qIMiKPvVhLnsH',
#       'id': '2iojnBLj0qIMiKPvVhLnsH',
#       'name': 'Trey Songz',
#       'type': 'artist',
#       'uri': 'spotify:artist:2iojnBLj0qIMiKPvVhLnsH'}],
#     'disc_number': 1,
#     'duration_ms': 364120,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21700341'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2pqr9hcN6AVdlbgqw8ULPk'},
#     'href': 'https://api.spotify.com/v1/tracks/2pqr9hcN6AVdlbgqw8ULPk',
#     'id': '2pqr9hcN6AVdlbgqw8ULPk',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Sheets...Still',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f8fb87b56845ce0fe6e5f6d67dcd22117fe4a0c5?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2pqr9hcN6AVdlbgqw8ULPk'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0urTpYCsixqZwgNTkPJOJ4'},
#        'href': 'https://api.spotify.com/v1/artists/0urTpYCsixqZwgNTkPJOJ4',
#        'id': '0urTpYCsixqZwgNTkPJOJ4',
#        'name': 'Aaliyah',
#        'type': 'artist',
#        'uri': 'spotify:artist:0urTpYCsixqZwgNTkPJOJ4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2TnI2Xr5FS0pZuFJh9XT1I'},
#      'href': 'https://api.spotify.com/v1/albums/2TnI2Xr5FS0pZuFJh9XT1I',
#      'id': '2TnI2Xr5FS0pZuFJh9XT1I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/266a2c3d4e8762e19c8bd42728ccdbca01f80158',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/360624c500efb199ba0dd7d51e1066b3a398cc86',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/63693d24b59a374d13f960e051cf2b1d52fb22f1',
#        'width': 64}],
#      'name': "Age Ain't Nothing But A Number",
#      'release_date': '1994',
#      'release_date_precision': 'year',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:2TnI2Xr5FS0pZuFJh9XT1I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0urTpYCsixqZwgNTkPJOJ4'},
#       'href': 'https://api.spotify.com/v1/artists/0urTpYCsixqZwgNTkPJOJ4',
#       'id': '0urTpYCsixqZwgNTkPJOJ4',
#       'name': 'Aaliyah',
#       'type': 'artist',
#       'uri': 'spotify:artist:0urTpYCsixqZwgNTkPJOJ4'}],
#     'disc_number': 1,
#     'duration_ms': 289893,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19400005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Xn6BioBEOrQnBN0yRrr4p'},
#     'href': 'https://api.spotify.com/v1/tracks/3Xn6BioBEOrQnBN0yRrr4p',
#     'id': '3Xn6BioBEOrQnBN0yRrr4p',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'At Your Best (You Are Love)',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1bcb93f02ec490a5e377dbb5ad00c1a2c7c71806?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3Xn6BioBEOrQnBN0yRrr4p'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XIKGBo9PnK1ApI5tZA60d'},
#        'href': 'https://api.spotify.com/v1/artists/0XIKGBo9PnK1ApI5tZA60d',
#        'id': '0XIKGBo9PnK1ApI5tZA60d',
#        'name': 'DaniLeigh',
#        'type': 'artist',
#        'uri': 'spotify:artist:0XIKGBo9PnK1ApI5tZA60d'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dWr9muDnTuBp3diyKHpTo'},
#      'href': 'https://api.spotify.com/v1/albums/5dWr9muDnTuBp3diyKHpTo',
#      'id': '5dWr9muDnTuBp3diyKHpTo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/77eb7c17cafe55032c14a4e0bbc1ad44c7ceb8f3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/77eb7c17cafe5502a6d4f600de0574ec50060c05',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/77eb7c17cafe55018cd5c06fd4e4b903bbdd4c7d',
#        'width': 64}],
#      'name': 'The Plan',
#      'release_date': '2018-11-30',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:5dWr9muDnTuBp3diyKHpTo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XIKGBo9PnK1ApI5tZA60d'},
#       'href': 'https://api.spotify.com/v1/artists/0XIKGBo9PnK1ApI5tZA60d',
#       'id': '0XIKGBo9PnK1ApI5tZA60d',
#       'name': 'DaniLeigh',
#       'type': 'artist',
#       'uri': 'spotify:artist:0XIKGBo9PnK1ApI5tZA60d'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#       'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK',
#       'id': '5f7VJjfbwm532GiveGC0ZK',
#       'name': 'Lil Baby',
#       'type': 'artist',
#       'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'}],
#     'disc_number': 1,
#     'duration_ms': 174720,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71818506'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2fwkl5Z8ujDtAh6qxEA5x0'},
#     'href': 'https://api.spotify.com/v1/tracks/2fwkl5Z8ujDtAh6qxEA5x0',
#     'id': '2fwkl5Z8ujDtAh6qxEA5x0',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7esO3L3DP7bM2OOd0Rdb4W'},
#      'href': 'https://api.spotify.com/v1/tracks/7esO3L3DP7bM2OOd0Rdb4W',
#      'id': '7esO3L3DP7bM2OOd0Rdb4W',
#      'type': 'track',
#      'uri': 'spotify:track:7esO3L3DP7bM2OOd0Rdb4W'},
#     'name': 'Lil Bebe (feat. Lil Baby) - Remix',
#     'popularity': 77,
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:2fwkl5Z8ujDtAh6qxEA5x0'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7urq0VfqxEYEEiZUkebXT4'},
#        'href': 'https://api.spotify.com/v1/artists/7urq0VfqxEYEEiZUkebXT4',
#        'id': '7urq0VfqxEYEEiZUkebXT4',
#        'name': '112',
#        'type': 'artist',
#        'uri': 'spotify:artist:7urq0VfqxEYEEiZUkebXT4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lSLGYViKHz22S8gEXz9Vc'},
#      'href': 'https://api.spotify.com/v1/albums/5lSLGYViKHz22S8gEXz9Vc',
#      'id': '5lSLGYViKHz22S8gEXz9Vc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/88b2c2f4db2b8daf95d9b329c94630187a978a83',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/917a2db7072fbebc2143bd89793ee432d06ff0d7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f2a11b0cd31c54ac557f25d699fac6fa363cd35c',
#        'width': 64}],
# ...
#     'href': 'https://api.spotify.com/v1/tracks/58s4iqgXFzXhBndBkg2AaD',
#     'id': '58s4iqgXFzXhBndBkg2AaD',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Spend My Life With You',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0ea395eda627aa1fd4dedb505f5e3b820e2780b8?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:58s4iqgXFzXhBndBkg2AaD'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fpTMHe34LC5t3h5ztK8qu'},
#        'href': 'https://api.spotify.com/v1/artists/4fpTMHe34LC5t3h5ztK8qu',
#        'id': '4fpTMHe34LC5t3h5ztK8qu',
#        'name': 'The Carters',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fpTMHe34LC5t3h5ztK8qu'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7jbdod8XNRfe2nIhppht46'},
#      'href': 'https://api.spotify.com/v1/albums/7jbdod8XNRfe2nIhppht46',
#      'id': '7jbdod8XNRfe2nIhppht46',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/d9660c83d41bda23ca003a87a9b902c3ea485d9d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/291be93de91331b64e8c99c3e8f20e066598a0d1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/88cf139eb939eb244568f404adfe088c4fabd55d',
#        'width': 64}],
#      'name': 'EVERYTHING IS LOVE',
#      'release_date': '2018-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:7jbdod8XNRfe2nIhppht46'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fpTMHe34LC5t3h5ztK8qu'},
#       'href': 'https://api.spotify.com/v1/artists/4fpTMHe34LC5t3h5ztK8qu',
#       'id': '4fpTMHe34LC5t3h5ztK8qu',
#       'name': 'The Carters',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fpTMHe34LC5t3h5ztK8qu'}],
#     'disc_number': 1,
#     'duration_ms': 190026,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMJMT1801774'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3a5xe1vquNB7CaxSyTTRpL'},
#     'href': 'https://api.spotify.com/v1/tracks/3a5xe1vquNB7CaxSyTTRpL',
#     'id': '3a5xe1vquNB7CaxSyTTRpL',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4imKIkVUzP2Qmf4QeMGrPQ'},
#      'href': 'https://api.spotify.com/v1/tracks/4imKIkVUzP2Qmf4QeMGrPQ',
#      'id': '4imKIkVUzP2Qmf4QeMGrPQ',
#      'type': 'track',
#      'uri': 'spotify:track:4imKIkVUzP2Qmf4QeMGrPQ'},
#     'name': 'HEARD ABOUT US',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5606b14cdc6c6628433d65c0ad85d813856256e8?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3a5xe1vquNB7CaxSyTTRpL'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#        'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#        'id': '2NdeV5rLm47xAvogXrYhJX',
#        'name': 'Ciara',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1vxEYHEzZI2l1AyZOtVHKJ'},
#      'href': 'https://api.spotify.com/v1/albums/1vxEYHEzZI2l1AyZOtVHKJ',
#      'id': '1vxEYHEzZI2l1AyZOtVHKJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/13186ab3249351eec7a227c48352f742320d78ab',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/78615f92d6c9e35d70743333c1fa7be529321d22',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/655ec171e6b76ea2548a11a8ef23136958c9ef3e',
#        'width': 64}],
#      'name': 'Jackie (Deluxe)',
#      'release_date': '2015-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:1vxEYHEzZI2l1AyZOtVHKJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#       'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#       'id': '2NdeV5rLm47xAvogXrYhJX',
#       'name': 'Ciara',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'}],
#     'disc_number': 1,
#     'duration_ms': 287933,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM11500082'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/20lNo44eUUCnyNNInzwkv9'},
#     'href': 'https://api.spotify.com/v1/tracks/20lNo44eUUCnyNNInzwkv9',
#     'id': '20lNo44eUUCnyNNInzwkv9',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Bet',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e3a29faed8cfd6e60bb642661c676337a43f7cfa?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:20lNo44eUUCnyNNInzwkv9'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#        'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#        'id': '7bXgB6jMjp9ATFy66eO08Z',
#        'name': 'Chris Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3zak0kNLcOY5vFcB3Ipskp'},
#      'href': 'https://api.spotify.com/v1/albums/3zak0kNLcOY5vFcB3Ipskp',
#      'id': '3zak0kNLcOY5vFcB3Ipskp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3135401b9bf1eb3e70b50639078f991bf08b2765',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/2d30383f8061087e0377a8fd737e81f915057736',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/109bf3d05ff9a1a4cf15577bae1c09bd8653c0d6',
#        'width': 64}],
#      'name': 'Heartbreak on a Full Moon',
#      'release_date': '2017-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3zak0kNLcOY5vFcB3Ipskp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#       'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#       'id': '7bXgB6jMjp9ATFy66eO08Z',
#       'name': 'Chris Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#     'disc_number': 1,
#     'duration_ms': 178787,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC11702713'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5WAOIxI6GVlUl27aLdVNJD'},
#     'href': 'https://api.spotify.com/v1/tracks/5WAOIxI6GVlUl27aLdVNJD',
#     'id': '5WAOIxI6GVlUl27aLdVNJD',
#     'is_local': False,
#     'is_playable': True,
#     'name': "This Ain't",
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8a87e783d46405fefe87bb985518c77c696f9669?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:5WAOIxI6GVlUl27aLdVNJD'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2retT7MFwHDVTeGKDdybEx'},
#        'href': 'https://api.spotify.com/v1/artists/2retT7MFwHDVTeGKDdybEx',
#        'id': '2retT7MFwHDVTeGKDdybEx',
#        'name': 'K. Michelle',
#        'type': 'artist',
#        'uri': 'spotify:artist:2retT7MFwHDVTeGKDdybEx'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2nIA5nr4NS4aYi5VWaUn5o'},
#      'href': 'https://api.spotify.com/v1/albums/2nIA5nr4NS4aYi5VWaUn5o',
#      'id': '2nIA5nr4NS4aYi5VWaUn5o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/0f8956ba7d283dcbad1ae4d41df2f280505451dc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/2eacee1e2d4db1ba420ff57a1dbe374d6fc5776b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/00d398de2c1c4bdde9a3b09d25ac8c705c393a77',
#        'width': 64}],
#      'name': 'KIMBERLY: The People I Used To Know',
#      'release_date': '2017-12-08',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:2nIA5nr4NS4aYi5VWaUn5o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2retT7MFwHDVTeGKDdybEx'},
#       'href': 'https://api.spotify.com/v1/artists/2retT7MFwHDVTeGKDdybEx',
#       'id': '2retT7MFwHDVTeGKDdybEx',
#       'name': 'K. Michelle',
#       'type': 'artist',
#       'uri': 'spotify:artist:2retT7MFwHDVTeGKDdybEx'}],
#     'disc_number': 1,
#     'duration_ms': 243013,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21703656'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4XwyvJkhmLpNtvOPWrQX4J'},
#     'href': 'https://api.spotify.com/v1/tracks/4XwyvJkhmLpNtvOPWrQX4J',
#     'id': '4XwyvJkhmLpNtvOPWrQX4J',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Birthday',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0432411c1f73041c044f1440d7d43201b0e56d09?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4XwyvJkhmLpNtvOPWrQX4J'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YG3fiiee6tHuimu1klAMg'},
#        'href': 'https://api.spotify.com/v1/artists/0YG3fiiee6tHuimu1klAMg',
#        'id': '0YG3fiiee6tHuimu1klAMg',
#        'name': 'J. Valentine',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YG3fiiee6tHuimu1klAMg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3gS3Hrq5Y04qhPgmGPqnhv'},
#      'href': 'https://api.spotify.com/v1/albums/3gS3Hrq5Y04qhPgmGPqnhv',
#      'id': '3gS3Hrq5Y04qhPgmGPqnhv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/726e1c2d5afdfbf60dfd67697609ef7f1a4d0d5e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/800f00bb2a62bb51fef6d56960f296a58ee6a957',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/7e563dba0e58ad254224d74c520ea31f6f09cbb1',
#        'width': 64}],
#      'name': 'UP! (R&B Remix) (feat. Chris Brown & Pleasure P) - Single',
#      'release_date': '2013-01-29',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3gS3Hrq5Y04qhPgmGPqnhv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YG3fiiee6tHuimu1klAMg'},
#       'href': 'https://api.spotify.com/v1/artists/0YG3fiiee6tHuimu1klAMg',
#       'id': '0YG3fiiee6tHuimu1klAMg',
#       'name': 'J. Valentine',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YG3fiiee6tHuimu1klAMg'}],
#     'disc_number': 1,
#     'duration_ms': 201142,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUYG1025857'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6tZmrNnFao9ofNviYqJwOH'},
#     'href': 'https://api.spotify.com/v1/tracks/6tZmrNnFao9ofNviYqJwOH',
#     'id': '6tZmrNnFao9ofNviYqJwOH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'UP! (feat. Chris Brown, Pleasure P) (R&B Remix Mix) - R&B Remix',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c4e11bca52a937fafb98f1ba3ca36d937b58c00b?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6tZmrNnFao9ofNviYqJwOH'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HgF4KnohByNElYid7iCNb'},
#        'href': 'https://api.spotify.com/v1/artists/4HgF4KnohByNElYid7iCNb',
#        'id': '4HgF4KnohByNElYid7iCNb',
#        'name': 'Bobby V.',
#        'type': 'artist',
#        'uri': 'spotify:artist:4HgF4KnohByNElYid7iCNb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6tiqcLj9TP3qaxWUbNuPYn'},
#      'href': 'https://api.spotify.com/v1/albums/6tiqcLj9TP3qaxWUbNuPYn',
#      'id': '6tiqcLj9TP3qaxWUbNuPYn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/8c835caf90019898e1791e17c255647dbd8a022c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8a2a6712a20a953c211e9440fc4f9b87096d2094',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5e8124f38f642f3aa5dd026004ec62f6f28766e0',
#        'width': 64}],
#      'name': 'Disturbing Tha Peace Presents Bobby Valentino',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:6tiqcLj9TP3qaxWUbNuPYn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4HgF4KnohByNElYid7iCNb'},
#       'href': 'https://api.spotify.com/v1/artists/4HgF4KnohByNElYid7iCNb',
#       'id': '4HgF4KnohByNElYid7iCNb',
#       'name': 'Bobby V.',
#       'type': 'artist',
#       'uri': 'spotify:artist:4HgF4KnohByNElYid7iCNb'}],
#     'disc_number': 1,
#     'duration_ms': 258666,
#     'explicit': False,
#     'external_ids': {'isrc': 'USDJ20500006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Ilen0VxPEsVRLpnePji8P'},
#     'href': 'https://api.spotify.com/v1/tracks/4Ilen0VxPEsVRLpnePji8P',
#     'id': '4Ilen0VxPEsVRLpnePji8P',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3SfZpKjMwvUQKGCty1dJ0T'},
#      'href': 'https://api.spotify.com/v1/tracks/3SfZpKjMwvUQKGCty1dJ0T',
#      'id': '3SfZpKjMwvUQKGCty1dJ0T',
#      'type': 'track',
#      'uri': 'spotify:track:3SfZpKjMwvUQKGCty1dJ0T'},
#     'name': 'Slow Down - 12" Version',
#     'popularity': 68,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4Ilen0VxPEsVRLpnePji8P'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iHNK0tOyZPYnBU7nGAgpQ'},
#        'href': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ',
#        'id': '4iHNK0tOyZPYnBU7nGAgpQ',
#        'name': 'Mariah Carey',
#        'type': 'artist',
#        'uri': 'spotify:artist:4iHNK0tOyZPYnBU7nGAgpQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3l6wov8ESqx6Z9ebLJdKDh'},
#      'href': 'https://api.spotify.com/v1/albums/3l6wov8ESqx6Z9ebLJdKDh',
#      'id': '3l6wov8ESqx6Z9ebLJdKDh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ccabae9efb449210f58dfbe65e15eed49029a8d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/bc3e6a79e09e7b96771b4aee13091c92470038d8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/febaff9d63043713b0d2431b1ae5906737fa552a',
#        'width': 64}],
#      'name': 'GTFO',
#      'release_date': '2018-09-13',
#      'release_date_precision': 'day',
#      'total_tracks': 0,
#      'type': 'album',
#      'uri': 'spotify:album:3l6wov8ESqx6Z9ebLJdKDh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iHNK0tOyZPYnBU7nGAgpQ'},
#       'href': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ',
#       'id': '4iHNK0tOyZPYnBU7nGAgpQ',
#       'name': 'Mariah Carey',
#       'type': 'artist',
#       'uri': 'spotify:artist:4iHNK0tOyZPYnBU7nGAgpQ'}],
#     'disc_number': 1,
#     'duration_ms': 207124,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM11807159'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3MBHhhVQiGLX28NolyIdY1'},
#     'href': 'https://api.spotify.com/v1/tracks/3MBHhhVQiGLX28NolyIdY1',
#     'id': '3MBHhhVQiGLX28NolyIdY1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'GTFO',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6ecc50c44c4131fb5fae0877e0efa7858372fc44?cid=2157f6e0361845908c5d15abb8eb5050',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3MBHhhVQiGLX28NolyIdY1'}]},
#  'success': True}
